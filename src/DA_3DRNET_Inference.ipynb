# %% [markdown]
# # Domain Adaptation Predictions

# %% [markdown]
# ## Intro
# Given a list of nii.gz files inside a folder, makes a brain mask and a ROI mask prediction with a given loaded model

# %% [markdown]
# ## Libraries

# %%
# utils
from utils.utils import save_excel_table
from utils.nifti import estimate_volume

# visualization
from utils.vedo import plot_slicer_cloud, plot_volume_cloud

# neural imaging
import nibabel as nib

# tensorflow
import tensorflow as tf
from evaluation.metrics import *

# other
import os
import importlib
import numpy as np

# make numpy printouts easier to read.
np.set_printoptions(precision=3, suppress=True)
print("Num GPUs Available: ", len(tf.config.list_physical_devices('GPU')))
# Out:
# Num GPUs Available:  1

# %% [markdown]
# ## Configuration
# Here it's possible to change some paramaters to make predictions

# %% [markdown]
# Paths:
# - dataset_folder (string): path to the folder that contains the files on which we want to make predictions
# - save_folder (string): path to the folder in which we want to save the predictions

# %%
dataset_folder = r'I:\\DannoCerebraleAcuto_MRI\\PNRR BATMAN Microbiota\\'
save_folder = dataset_folder

# %% [markdown]
# Save results:
# - save (boolean): if true, saves the predictions in save_folder

# %%
save = True

# %% [markdown]
# 3D preview:
# - show_3d_preview (boolean): shows the predicted mask in an external window

# %%
show_3d_preview = False

# %% [markdown]
# Morphological smoothing:
# - remove_small_objects (boolean): if true, removes small unconnected regions based on object_min_area
# - object_min_area (int): the smallest allowable contiguos region size, in voxels
# - fill_small_holes (boolean): if true, fills small holes
# - holes_max_area (int): the maximum area, in voxels, of a contiguous hole that will be filled

# %%
remove_small_objects = True
object_min_area = 30000
fill_small_holes = True
holes_max_area = 20000

# %% [markdown]
# Prediction parameters:
# - patch_size (tuple): size of the sliding window used to extract patches from the image
# - patch_resolution (tuple): desired target resolution for all patch (should be equal to the training resolution of the model)
# - stride (int): translation offset of the sliding window (less is better but requires more computational time)
#
# Suggested stride values: 6,8,12,16

# %%
patch_size = (80,80,80) #voxels
patch_resolution = (0.1,0.1,0.1) #mm
stride = 20
threshold = 0.5

# %% [markdown]
# Input and output filenames:

# %%
# Input Image
input_postfix = '_anat_orig.nii.gz'

# Output Masks
brain_prediction_postfix = '_brain_mask_r3dnet.nii.gz'
roi_prediction_postfix = f'_regions_r3dnet.nii.gz'

# Excel Table Name
excel_name = f'predicted_r3dnet_volumes.xlsx'

# %% [markdown]
# To make a prediction, the program expects a standard folder structure similar to the following:
# ```python
# target_folder/
#   FLASH/
#     ID_MICE_A/
#       Anat/
#         ID_MICE_A_N4.nii.gz
#         ...
#     ID_MICE_B/
#       Anat/
#         ID_MICE_B_N4.nii.gz
#         ...
#   DTI/
#     ID_MICE_F/
#       dti/
#         ID_MICE_F_N4.nii.gz
#         ...
#   Other.../
# ```
# In this structure, there is a folder for each group of mice, such as `FLASH`, `RARE`, or `Group_1`.
#
# Inside each group folder, it is **strictly required** that each mouse file name starts with the same folder name as that of the mouse.
#
# For example, the `ID_MICE_A` folder should contain only files starting with `ID_MICE_A`. The subfolder (e.g., `Anat`) and the postfix file name extension (e.g., `N4`) can be modified later if needed.
#
# You can specify the modalities directories in the following variable:
#
# ```python
# modalities_directories = {
#     'FLASH': 'Anat',
#     'RARE': 'Anat',
#     'DTI': 'dti',
#     # Add more modalities as needed
# }
# ```

# %%
# Folder structure for structured mode
modalities_directories = {
    'Exp SCFA': 'Anat',
}

# Output labels ( Network -> Output mask labels)
labels_mapping = {
    0: 0, #0
    1: 1, #1
    2: 0, #2
    3: 3, #3
    4: 0, #5
    5: 0, #6
    6: 0, #12
    7: 13, #13
    8: 0, #15
    9: 0, #16
    10: 21, #21
}


name_mapping = {
    0: {'name': 'Background', 'value': 0},
    1: {'name': 'Lesion', 'value': 1},
    2: {'name': 'Ipsi Ventricle', 'value': 3},
    3: {'name': 'Contra Ventricle', 'value': 13},
    4: {'name': 'Third Ventricle', 'value': 21}
}

num_classes = len(labels_mapping)

# %% [markdown]
# From here the code should remain unchanged

# %%
input_channels = 1

# MODEL_NAME = 'mice_roi_unet_ep500_18-05-2024_13-25' # Alzato std random cropping
# MODEL_NAME = 'mice_roi_unet_ep500_18-05-2024_21-53' # Domain split attention
# MODEL_NAME = 'mice_roi_unet_ep500_19-05-2024_03-45' # Attention 2.0
# MODEL_NAME = 'mice_roi_unet_ep500_19-05-2024_14-35' # Attention 2.0 + old losses
# MODEL_NAME = 'mice_roi_unet_ep500_19-05-2024_17-08' # Attention 2.0 + 2x sampling (no miss)
# MODEL_NAME = 'mice_roi_unet_ep500_19-05-2024_23-18' # 2x sampling (miss)
# MODEL_NAME = 'mice_roi_unet_ep500_20-05-2024_00-53' # 2x sampling 
# MODEL_NAME = 'mice_roi_unet_ep500_20-05-2024_18-46' # 2x sampling + no classificator (check this out)
# MODEL_NAME = 'mice_roi_unet_ep500_21-05-2024_02-35' # 2x sampling + more dense neuons
# MODEL_NAME = 'mice_roi_unet_ep500_21-05-2024_14-06' # 2x sampling + deeper network
# MODEL_NAME = 'mice_roi_unet_ep500_22-05-2024_11-58' # 2x sampling + deeper network 
MODEL_NAME = 'mice_roi_unet_ep500_22-05-2024_15-25' # 2x sampling + deeper network + domain attention best so far
MODEL_NAME = 'mice_roi_unet_ep500_29-06-2024_01-22' # final model
MODEL_NAME = 'rnet_da.h5'

full_name = 'model_fold_0.h5'
full_name = 'save_' + MODEL_NAME + '.h5'
model_path = '../results/' + MODEL_NAME + '/' + full_name
model_path = '../models/' + MODEL_NAME

# %%
process_id = None

# %% [markdown]
# ## Load the model
# Load a previously trained model to start making predictions

# %%
import models.networks
from evaluation.metrics import *
from evaluation.losses import *

model = tf.keras.models.load_model(model_path,
                                   custom_objects={ "loss": diceCELoss(),
                                                    "precision": precision_coefficient(),
                                                    "sensitivity": sensitivity_coefficient(),
                                                    "specificity": specificity_coefficient(),
                                                    "K": tf.keras.backend,
                                                    "training": False,
                                                  }, compile=False)

model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, None, None,  0           []
#                                  None, 1)]
#
#  conv3d_10 (Conv3D)             (None, None, None,   448         ['input_1[0][0]']
#                                 None, 16)
#
#  batch_normalization_6 (BatchNo  (None, None, None,   64         ['conv3d_10[0][0]']
#  rmalization)                   None, 16)
#
#  average_pooling3d (AveragePool  (None, None, None,   0          ['input_1[0][0]']
#  ing3D)                         None, 1)
#
#  conv3d_11 (Conv3D)             (None, None, None,   6928        ['batch_normalization_6[0][0]']
#                                 None, 16)
#
#  conv3d_1 (Conv3D)              (None, None, None,   896         ['average_pooling3d[0][0]']
#                                 None, 32)
#
#  batch_normalization_7 (BatchNo  (None, None, None,   64         ['conv3d_11[0][0]']
#  rmalization)                   None, 16)
#
#  conv3d_9 (Conv3D)              (None, None, None,   32          ['input_1[0][0]']
#                                 None, 16)
#
#  batch_normalization (BatchNorm  (None, None, None,   128        ['conv3d_1[0][0]']
#  alization)                     None, 32)
#
#  add_3 (Add)                    (None, None, None,   0           ['batch_normalization_7[0][0]',
#                                 None, 16)                         'conv3d_9[0][0]']
#
#  conv3d_2 (Conv3D)              (None, None, None,   27680       ['batch_normalization[0][0]']
#                                 None, 32)
#
#  activation_3 (Activation)      (None, None, None,   0           ['add_3[0][0]']
#                                 None, 16)
#
#  batch_normalization_1 (BatchNo  (None, None, None,   128        ['conv3d_2[0][0]']
#  rmalization)                   None, 32)
#
#  conv3d (Conv3D)                (None, None, None,   64          ['average_pooling3d[0][0]']
#                                 None, 32)
#
#  max_pooling3d (MaxPooling3D)   (None, None, None,   0           ['activation_3[0][0]']
#                                 None, 16)
#
#  add (Add)                      (None, None, None,   0           ['batch_normalization_1[0][0]',
#                                 None, 32)                         'conv3d[0][0]']
#
#  spatial_dropout3d (SpatialDrop  (None, None, None,   0          ['max_pooling3d[0][0]']
#  out3D)                         None, 16)
#
#  activation (Activation)        (None, None, None,   0           ['add[0][0]']
#                                 None, 32)
#
#  concatenate (Concatenate)      (None, None, None,   0           ['spatial_dropout3d[0][0]',
#                                 None, 48)                         'activation[0][0]']
#
#  conv3d_13 (Conv3D)             (None, None, None,   41504       ['concatenate[0][0]']
#                                 None, 32)
#
#  batch_normalization_8 (BatchNo  (None, None, None,   128        ['conv3d_13[0][0]']
#  rmalization)                   None, 32)
#
#  average_pooling3d_1 (AveragePo  (None, None, None,   0          ['average_pooling3d[0][0]']
#  oling3D)                       None, 1)
#
#  conv3d_14 (Conv3D)             (None, None, None,   27680       ['batch_normalization_8[0][0]']
#                                 None, 32)
#
#  conv3d_4 (Conv3D)              (None, None, None,   1792        ['average_pooling3d_1[0][0]']
#                                 None, 64)
#
#  batch_normalization_9 (BatchNo  (None, None, None,   128        ['conv3d_14[0][0]']
#  rmalization)                   None, 32)
#
#  conv3d_12 (Conv3D)             (None, None, None,   1568        ['concatenate[0][0]']
#                                 None, 32)
#
#  batch_normalization_2 (BatchNo  (None, None, None,   256        ['conv3d_4[0][0]']
#  rmalization)                   None, 64)
#
#  add_4 (Add)                    (None, None, None,   0           ['batch_normalization_9[0][0]',
#                                 None, 32)                         'conv3d_12[0][0]']
#
#  conv3d_5 (Conv3D)              (None, None, None,   110656      ['batch_normalization_2[0][0]']
#                                 None, 64)
#
#  activation_4 (Activation)      (None, None, None,   0           ['add_4[0][0]']
#                                 None, 32)
#
#  batch_normalization_3 (BatchNo  (None, None, None,   256        ['conv3d_5[0][0]']
#  rmalization)                   None, 64)
#
#  conv3d_3 (Conv3D)              (None, None, None,   128         ['average_pooling3d_1[0][0]']
#                                 None, 64)
#
#  max_pooling3d_1 (MaxPooling3D)  (None, None, None,   0          ['activation_4[0][0]']
#                                 None, 32)
#
#  add_1 (Add)                    (None, None, None,   0           ['batch_normalization_3[0][0]',
#                                 None, 64)                         'conv3d_3[0][0]']
#
#  spatial_dropout3d_1 (SpatialDr  (None, None, None,   0          ['max_pooling3d_1[0][0]']
#  opout3D)                       None, 32)
#
#  activation_1 (Activation)      (None, None, None,   0           ['add_1[0][0]']
#                                 None, 64)
#
#  concatenate_1 (Concatenate)    (None, None, None,   0           ['spatial_dropout3d_1[0][0]',
#                                 None, 96)                         'activation_1[0][0]']
#
#  conv3d_16 (Conv3D)             (None, None, None,   165952      ['concatenate_1[0][0]']
#                                 None, 64)
#
#  batch_normalization_10 (BatchN  (None, None, None,   256        ['conv3d_16[0][0]']
#  ormalization)                  None, 64)
#
#  average_pooling3d_2 (AveragePo  (None, None, None,   0          ['average_pooling3d_1[0][0]']
#  oling3D)                       None, 1)
#
#  conv3d_17 (Conv3D)             (None, None, None,   110656      ['batch_normalization_10[0][0]']
#                                 None, 64)
#
#  conv3d_7 (Conv3D)              (None, None, None,   3584        ['average_pooling3d_2[0][0]']
#                                 None, 128)
#
#  batch_normalization_11 (BatchN  (None, None, None,   256        ['conv3d_17[0][0]']
#  ormalization)                  None, 64)
#
#  conv3d_15 (Conv3D)             (None, None, None,   6208        ['concatenate_1[0][0]']
#                                 None, 64)
#
#  batch_normalization_4 (BatchNo  (None, None, None,   512        ['conv3d_7[0][0]']
#  rmalization)                   None, 128)
#
#  add_5 (Add)                    (None, None, None,   0           ['batch_normalization_11[0][0]',
#                                 None, 64)                         'conv3d_15[0][0]']
#
#  conv3d_8 (Conv3D)              (None, None, None,   442496      ['batch_normalization_4[0][0]']
#                                 None, 128)
#
#  activation_5 (Activation)      (None, None, None,   0           ['add_5[0][0]']
#                                 None, 64)
#
#  batch_normalization_5 (BatchNo  (None, None, None,   512        ['conv3d_8[0][0]']
#  rmalization)                   None, 128)
#
#  conv3d_6 (Conv3D)              (None, None, None,   256         ['average_pooling3d_2[0][0]']
#                                 None, 128)
#
#  max_pooling3d_2 (MaxPooling3D)  (None, None, None,   0          ['activation_5[0][0]']
#                                 None, 64)
#
#  add_2 (Add)                    (None, None, None,   0           ['batch_normalization_5[0][0]',
#                                 None, 128)                        'conv3d_6[0][0]']
#
#  spatial_dropout3d_2 (SpatialDr  (None, None, None,   0          ['max_pooling3d_2[0][0]']
#  opout3D)                       None, 64)
#
#  activation_2 (Activation)      (None, None, None,   0           ['add_2[0][0]']
#                                 None, 128)
#
#  concatenate_2 (Concatenate)    (None, None, None,   0           ['spatial_dropout3d_2[0][0]',
#                                 None, 192)                        'activation_2[0][0]']
#
#  conv3d_19 (Conv3D)             (None, None, None,   663680      ['concatenate_2[0][0]']
#                                 None, 128)
#
#  batch_normalization_12 (BatchN  (None, None, None,   512        ['conv3d_19[0][0]']
#  ormalization)                  None, 128)
#
#  conv3d_20 (Conv3D)             (None, None, None,   442496      ['batch_normalization_12[0][0]']
#                                 None, 128)
#
#  batch_normalization_13 (BatchN  (None, None, None,   512        ['conv3d_20[0][0]']
#  ormalization)                  None, 128)
#
#  conv3d_18 (Conv3D)             (None, None, None,   24704       ['concatenate_2[0][0]']
#                                 None, 128)
#
#  add_6 (Add)                    (None, None, None,   0           ['batch_normalization_13[0][0]',
#                                 None, 128)                        'conv3d_18[0][0]']
#
#  activation_6 (Activation)      (None, None, None,   0           ['add_6[0][0]']
#                                 None, 128)
#
#  max_pooling3d_3 (MaxPooling3D)  (None, None, None,   0          ['activation_6[0][0]']
#                                 None, 128)
#
#  spatial_dropout3d_3 (SpatialDr  (None, None, None,   0          ['max_pooling3d_3[0][0]']
#  opout3D)                       None, 128)
#
#  conv3d_22 (Conv3D)             (None, None, None,   884992      ['spatial_dropout3d_3[0][0]']
#                                 None, 256)
#
#  batch_normalization_14 (BatchN  (None, None, None,   1024       ['conv3d_22[0][0]']
#  ormalization)                  None, 256)
#
#  conv3d_23 (Conv3D)             (None, None, None,   1769728     ['batch_normalization_14[0][0]']
#                                 None, 256)
#
#  batch_normalization_15 (BatchN  (None, None, None,   1024       ['conv3d_23[0][0]']
#  ormalization)                  None, 256)
#
#  conv3d_21 (Conv3D)             (None, None, None,   33024       ['spatial_dropout3d_3[0][0]']
#                                 None, 256)
#
#  add_7 (Add)                    (None, None, None,   0           ['batch_normalization_15[0][0]',
#                                 None, 256)                        'conv3d_21[0][0]']
#
#  activation_7 (Activation)      (None, None, None,   0           ['add_7[0][0]']
#                                 None, 256)
#
#  conv3d_24 (Conv3D)             (None, None, None,   32896       ['activation_7[0][0]']
#                                 None, 128)
#
#  conv3d_25 (Conv3D)             (None, None, None,   131200      ['activation_6[0][0]']
#                                 None, 128)
#
#  add_8 (Add)                    (None, None, None,   0           ['conv3d_24[0][0]',
#                                 None, 128)                        'conv3d_25[0][0]']
#
#  activation_8 (Activation)      (None, None, None,   0           ['add_8[0][0]']
#                                 None, 128)
#
#  conv3d_26 (Conv3D)             (None, None, None,   129         ['activation_8[0][0]']
#                                 None, 1)
#
#  activation_9 (Activation)      (None, None, None,   0           ['conv3d_26[0][0]']
#                                 None, 1)
#
#  up_sampling3d (UpSampling3D)   (None, None, None,   0           ['activation_9[0][0]']
#                                 None, 1)
#
#  lambda (Lambda)                (None, None, None,   0           ['up_sampling3d[0][0]']
#                                 None, 128)
#
#  multiply (Multiply)            (None, None, None,   0           ['lambda[0][0]',
#                                 None, 128)                        'activation_6[0][0]']
#
#  conv3d_transpose (Conv3DTransp  (None, None, None,   262272     ['activation_7[0][0]']
#  ose)                           None, 128)
#
#  conv3d_27 (Conv3D)             (None, None, None,   16512       ['multiply[0][0]']
#                                 None, 128)
#
#  batch_normalization_17 (BatchN  (None, None, None,   512        ['conv3d_transpose[0][0]']
#  ormalization)                  None, 128)
#
#  batch_normalization_16 (BatchN  (None, None, None,   512        ['conv3d_27[0][0]']
#  ormalization)                  None, 128)
#
#  concatenate_3 (Concatenate)    (None, None, None,   0           ['batch_normalization_17[0][0]',
#                                 None, 256)                        'batch_normalization_16[0][0]']
#
#  conv3d_29 (Conv3D)             (None, None, None,   884864      ['concatenate_3[0][0]']
#                                 None, 128)
#
#  batch_normalization_18 (BatchN  (None, None, None,   512        ['conv3d_29[0][0]']
#  ormalization)                  None, 128)
#
#  conv3d_30 (Conv3D)             (None, None, None,   442496      ['batch_normalization_18[0][0]']
#                                 None, 128)
#
#  batch_normalization_19 (BatchN  (None, None, None,   512        ['conv3d_30[0][0]']
#  ormalization)                  None, 128)
#
#  conv3d_28 (Conv3D)             (None, None, None,   32896       ['concatenate_3[0][0]']
#                                 None, 128)
#
#  add_9 (Add)                    (None, None, None,   0           ['batch_normalization_19[0][0]',
#                                 None, 128)                        'conv3d_28[0][0]']
#
#  activation_10 (Activation)     (None, None, None,   0           ['add_9[0][0]']
#                                 None, 128)
#
#  conv3d_31 (Conv3D)             (None, None, None,   8256        ['activation_10[0][0]']
#                                 None, 64)
#
#  conv3d_32 (Conv3D)             (None, None, None,   32832       ['activation_5[0][0]']
#                                 None, 64)
#
#  add_10 (Add)                   (None, None, None,   0           ['conv3d_31[0][0]',
#                                 None, 64)                         'conv3d_32[0][0]']
#
#  activation_11 (Activation)     (None, None, None,   0           ['add_10[0][0]']
#                                 None, 64)
#
#  conv3d_33 (Conv3D)             (None, None, None,   65          ['activation_11[0][0]']
#                                 None, 1)
#
#  activation_12 (Activation)     (None, None, None,   0           ['conv3d_33[0][0]']
#                                 None, 1)
#
#  up_sampling3d_1 (UpSampling3D)  (None, None, None,   0          ['activation_12[0][0]']
#                                 None, 1)
#
#  lambda_1 (Lambda)              (None, None, None,   0           ['up_sampling3d_1[0][0]']
#                                 None, 64)
#
#  multiply_1 (Multiply)          (None, None, None,   0           ['lambda_1[0][0]',
#                                 None, 64)                         'activation_5[0][0]']
#
#  conv3d_transpose_1 (Conv3DTran  (None, None, None,   65600      ['activation_10[0][0]']
#  spose)                         None, 64)
#
#  conv3d_34 (Conv3D)             (None, None, None,   4160        ['multiply_1[0][0]']
#                                 None, 64)
#
#  batch_normalization_21 (BatchN  (None, None, None,   256        ['conv3d_transpose_1[0][0]']
#  ormalization)                  None, 64)
#
#  batch_normalization_20 (BatchN  (None, None, None,   256        ['conv3d_34[0][0]']
#  ormalization)                  None, 64)
#
#  concatenate_4 (Concatenate)    (None, None, None,   0           ['batch_normalization_21[0][0]',
#                                 None, 128)                        'batch_normalization_20[0][0]']
#
#  conv3d_36 (Conv3D)             (None, None, None,   221248      ['concatenate_4[0][0]']
#                                 None, 64)
#
#  batch_normalization_22 (BatchN  (None, None, None,   256        ['conv3d_36[0][0]']
#  ormalization)                  None, 64)
#
#  conv3d_37 (Conv3D)             (None, None, None,   110656      ['batch_normalization_22[0][0]']
#                                 None, 64)
#
#  batch_normalization_23 (BatchN  (None, None, None,   256        ['conv3d_37[0][0]']
#  ormalization)                  None, 64)
#
#  conv3d_35 (Conv3D)             (None, None, None,   8256        ['concatenate_4[0][0]']
#                                 None, 64)
#
#  add_11 (Add)                   (None, None, None,   0           ['batch_normalization_23[0][0]',
#                                 None, 64)                         'conv3d_35[0][0]']
#
#  activation_13 (Activation)     (None, None, None,   0           ['add_11[0][0]']
#                                 None, 64)
#
#  conv3d_38 (Conv3D)             (None, None, None,   2080        ['activation_13[0][0]']
#                                 None, 32)
#
#  conv3d_39 (Conv3D)             (None, None, None,   8224        ['activation_4[0][0]']
#                                 None, 32)
#
#  add_12 (Add)                   (None, None, None,   0           ['conv3d_38[0][0]',
#                                 None, 32)                         'conv3d_39[0][0]']
#
#  activation_14 (Activation)     (None, None, None,   0           ['add_12[0][0]']
#                                 None, 32)
#
#  conv3d_40 (Conv3D)             (None, None, None,   33          ['activation_14[0][0]']
#                                 None, 1)
#
#  activation_15 (Activation)     (None, None, None,   0           ['conv3d_40[0][0]']
#                                 None, 1)
#
#  up_sampling3d_2 (UpSampling3D)  (None, None, None,   0          ['activation_15[0][0]']
#                                 None, 1)
#
#  lambda_2 (Lambda)              (None, None, None,   0           ['up_sampling3d_2[0][0]']
#                                 None, 32)
#
#  multiply_2 (Multiply)          (None, None, None,   0           ['lambda_2[0][0]',
#                                 None, 32)                         'activation_4[0][0]']
#
#  conv3d_transpose_2 (Conv3DTran  (None, None, None,   16416      ['activation_13[0][0]']
#  spose)                         None, 32)
#
#  conv3d_41 (Conv3D)             (None, None, None,   1056        ['multiply_2[0][0]']
#                                 None, 32)
#
#  batch_normalization_25 (BatchN  (None, None, None,   128        ['conv3d_transpose_2[0][0]']
#  ormalization)                  None, 32)
#
#  batch_normalization_24 (BatchN  (None, None, None,   128        ['conv3d_41[0][0]']
#  ormalization)                  None, 32)
#
#  concatenate_5 (Concatenate)    (None, None, None,   0           ['batch_normalization_25[0][0]',
#                                 None, 64)                         'batch_normalization_24[0][0]']
#
#  conv3d_43 (Conv3D)             (None, None, None,   55328       ['concatenate_5[0][0]']
#                                 None, 32)
#
#  batch_normalization_26 (BatchN  (None, None, None,   128        ['conv3d_43[0][0]']
#  ormalization)                  None, 32)
#
#  conv3d_44 (Conv3D)             (None, None, None,   27680       ['batch_normalization_26[0][0]']
#                                 None, 32)
#
#  batch_normalization_27 (BatchN  (None, None, None,   128        ['conv3d_44[0][0]']
#  ormalization)                  None, 32)
#
#  conv3d_42 (Conv3D)             (None, None, None,   2080        ['concatenate_5[0][0]']
#                                 None, 32)
#
#  add_13 (Add)                   (None, None, None,   0           ['batch_normalization_27[0][0]',
#                                 None, 32)                         'conv3d_42[0][0]']
#
#  activation_16 (Activation)     (None, None, None,   0           ['add_13[0][0]']
#                                 None, 32)
#
#  conv3d_45 (Conv3D)             (None, None, None,   528         ['activation_16[0][0]']
#                                 None, 16)
#
#  conv3d_46 (Conv3D)             (None, None, None,   2064        ['activation_3[0][0]']
#                                 None, 16)
#
#  add_14 (Add)                   (None, None, None,   0           ['conv3d_45[0][0]',
#                                 None, 16)                         'conv3d_46[0][0]']
#
#  activation_17 (Activation)     (None, None, None,   0           ['add_14[0][0]']
#                                 None, 16)
#
#  conv3d_47 (Conv3D)             (None, None, None,   17          ['activation_17[0][0]']
#                                 None, 1)
#
#  activation_18 (Activation)     (None, None, None,   0           ['conv3d_47[0][0]']
#                                 None, 1)
#
#  up_sampling3d_3 (UpSampling3D)  (None, None, None,   0          ['activation_18[0][0]']
#                                 None, 1)
#
#  lambda_3 (Lambda)              (None, None, None,   0           ['up_sampling3d_3[0][0]']
#                                 None, 16)
#
#  multiply_3 (Multiply)          (None, None, None,   0           ['lambda_3[0][0]',
#                                 None, 16)                         'activation_3[0][0]']
#
#  conv3d_transpose_3 (Conv3DTran  (None, None, None,   4112       ['activation_16[0][0]']
#  spose)                         None, 16)
#
#  conv3d_48 (Conv3D)             (None, None, None,   272         ['multiply_3[0][0]']
#                                 None, 16)
#
#  batch_normalization_29 (BatchN  (None, None, None,   64         ['conv3d_transpose_3[0][0]']
#  ormalization)                  None, 16)
#
#  batch_normalization_28 (BatchN  (None, None, None,   64         ['conv3d_48[0][0]']
#  ormalization)                  None, 16)
#
#  concatenate_6 (Concatenate)    (None, None, None,   0           ['batch_normalization_29[0][0]',
#                                 None, 32)                         'batch_normalization_28[0][0]']
#
#  conv3d_50 (Conv3D)             (None, None, None,   13840       ['concatenate_6[0][0]']
#                                 None, 16)
#
#  batch_normalization_30 (BatchN  (None, None, None,   64         ['conv3d_50[0][0]']
#  ormalization)                  None, 16)
#
#  conv3d_51 (Conv3D)             (None, None, None,   6928        ['batch_normalization_30[0][0]']
#                                 None, 16)
#
#  batch_normalization_31 (BatchN  (None, None, None,   64         ['conv3d_51[0][0]']
#  ormalization)                  None, 16)
#
#  conv3d_49 (Conv3D)             (None, None, None,   528         ['concatenate_6[0][0]']
#                                 None, 16)
#
#  add_15 (Add)                   (None, None, None,   0           ['batch_normalization_31[0][0]',
#                                 None, 16)                         'conv3d_49[0][0]']
#
#  global_average_pooling3d (Glob  (None, 256)         0           ['activation_7[0][0]']
#  alAveragePooling3D)
#
#  r_output_4 (Conv3D)            (None, None, None,   1419        ['activation_10[0][0]']
#                                 None, 11)
#
#  r_output_3 (Conv3D)            (None, None, None,   715         ['activation_13[0][0]']
#                                 None, 11)
#
#  r_output_2 (Conv3D)            (None, None, None,   363         ['activation_16[0][0]']
#                                 None, 11)
#
#  activation_19 (Activation)     (None, None, None,   0           ['add_15[0][0]']
#                                 None, 16)
#
#  b_output_4 (Conv3D)            (None, None, None,   129         ['activation_10[0][0]']
#                                 None, 1)
#
#  b_output_3 (Conv3D)            (None, None, None,   65          ['activation_13[0][0]']
#                                 None, 1)
#
#  b_output_2 (Conv3D)            (None, None, None,   33          ['activation_16[0][0]']
#                                 None, 1)
#
#  dense (Dense)                  (None, 512)          131584      ['global_average_pooling3d[0][0]'
#                                                                  ]
#
#  up_sampling3d_7 (UpSampling3D)  (None, None, None,   0          ['r_output_4[0][0]']
#                                 None, 11)
#
#  up_sampling3d_8 (UpSampling3D)  (None, None, None,   0          ['r_output_3[0][0]']
#                                 None, 11)
#
#  up_sampling3d_9 (UpSampling3D)  (None, None, None,   0          ['r_output_2[0][0]']
#                                 None, 11)
#
#  r_output_1 (Conv3D)            (None, None, None,   187         ['activation_19[0][0]']
#                                 None, 11)
#
#  up_sampling3d_4 (UpSampling3D)  (None, None, None,   0          ['b_output_4[0][0]']
#                                 None, 1)
#
#  up_sampling3d_5 (UpSampling3D)  (None, None, None,   0          ['b_output_3[0][0]']
#                                 None, 1)
#
#  up_sampling3d_6 (UpSampling3D)  (None, None, None,   0          ['b_output_2[0][0]']
#                                 None, 1)
#
#  b_output_1 (Conv3D)            (None, None, None,   17          ['activation_19[0][0]']
#                                 None, 1)
#
#  dropout (Dropout)              (None, 512)          0           ['dense[0][0]']
#
#  add_17 (Add)                   (None, None, None,   0           ['up_sampling3d_7[0][0]',
#                                 None, 11)                         'up_sampling3d_8[0][0]',
#                                                                   'up_sampling3d_9[0][0]',
#                                                                   'r_output_1[0][0]']
#
#  add_16 (Add)                   (None, None, None,   0           ['up_sampling3d_4[0][0]',
#                                 None, 1)                          'up_sampling3d_5[0][0]',
#                                                                   'up_sampling3d_6[0][0]',
#                                                                   'b_output_1[0][0]']
#
#  dense_1 (Dense)                (None, 256)          131328      ['dropout[0][0]']
#
#  conv3d_53 (Conv3D)             (None, None, None,   132         ['add_17[0][0]']
#                                 None, 11)
#
#  conv3d_52 (Conv3D)             (None, None, None,   2           ['add_16[0][0]']
#                                 None, 1)
#
#  dropout_1 (Dropout)            (None, 256)          0           ['dense_1[0][0]']
#
#  regions (Activation)           (None, None, None,   0           ['conv3d_53[0][0]']
#                                 None, 11)
#
#  brain_mask (Activation)        (None, None, None,   0           ['conv3d_52[0][0]']
#                                 None, 1)
#
#  classifier (Dense)             (None, 1)            257         ['dropout_1[0][0]']
#
# ==================================================================================================
# Total params: 7,438,507
# Trainable params: 7,433,707
# Non-trainable params: 4,800
# __________________________________________________________________________________________________

# %% [markdown]
# ## Preprocessing configuration
# The standard pipeline order is:
# 1. (opt.) Cut and pad the image to a default matrix dimension
# 2. (opt.) Correct x10 intensity values
# 3. Apply N4 Bias Field correction
# 4. Copy the orientation from the ref. image
# 5. Resample to a target resolution
# 6. Normalize the intensity values with z-score (default)

# %%
from preprocessing.preprocessor import Preprocessor, Resample, Reorient, Normalize, CorrectX10, N4BiasFieldCorrection, SaveNifti

# ref image for reorientation
ref_img = nib.load(os.path.join('../example', 'RARE', 'TBI_fm_19_49', 'Anat', 'TBI_fm_19_49_N4.nii.gz'))

# Create an instance of the MRIProcessor class
processor = Preprocessor([
    CorrectX10(),
    N4BiasFieldCorrection(),
    SaveNifti(postfix='_N4', replace=input_postfix),
    Reorient(ref_img),
    Resample(target_resolution=patch_resolution, interpolation=0),
    Normalize()
])

# %% [markdown]
# ## Final Inference for random cropping
# Makes the predictions by sliding through the input a patch volume of size (80,80,80) with a stridde of 20

# %%
from evaluation.inference import RandomCroppingPrediction

# Create an instance of the RandomCroppingPrediction class
predictor = RandomCroppingPrediction(model, patch_size=patch_size, stride=stride, threshold=threshold, num_classes=num_classes)

# %% [markdown]
# Make predictions for every file inside the folder

# %%
import evaluation.postprocessing
importlib.reload(evaluation.postprocessing)
from evaluation.postprocessing import morphology_refinement_callback


for modality, folder in modalities_directories.items():

    # if modalities folder does not exist, skip
    if not os.path.isdir(os.path.join(dataset_folder, modality)): 
        print(f'Folder {folder} not found, skipping')
        continue

    modality_folder = os.path.join(dataset_folder, modality)

    for case in os.listdir(modality_folder):

        # if not dir skip
        if not os.path.isdir(os.path.join(modality_folder, case)): continue
        
        # If case substring is not in the process_id list, skip
        if process_id and case not in process_id: continue
        
        if not os.path.isdir(os.path.join(modality_folder, case, folder)): print(f'Folder {folder} not found, skipping'); continue
        case_folder = os.path.join(modality_folder, case, folder)

        for file in os.listdir(case_folder):
            if file == case + input_postfix:
                print('\n|-',file, '-------------------\ \n')
                file_path = os.path.join(case_folder, file)
                
                # load image
                nii_img = nib.load(os.path.join(case_folder, file))

                # preprocess image
                x_prep = processor.preprocess(nii_img,  path=file_path)

                # create a mask for this new unseen file
                results = predictor.random_cropping_inference(x_prep, with_brain_mask=True)
                y_mask = results['brain_mask']
                y_regions = results['roi']

                # postprocessing
                y_mask = morphology_refinement_callback(fill_small_holes=fill_small_holes, holes_max_area=holes_max_area,remove_small_objects=remove_small_objects, object_min_area=object_min_area)(y_mask)

                # save
                y_pred_nifti = nib.Nifti1Image(y_regions, affine=x_prep.affine, dtype=np.float64, header=x_prep.header)
                y_pred_mask_nifti = nib.Nifti1Image(y_mask, affine=x_prep.affine, dtype=np.float64, header=x_prep.header)

                if show_3d_preview: plot_slicer_cloud(x_prep, y_pred_nifti)

                # return to original shape and resolution
                save_path = os.path.join(save_folder, modality, case, folder, case + roi_prediction_postfix)
                mask_save_path = os.path.join(save_folder, modality, case, folder, case + brain_prediction_postfix)
                final_image = processor.deprocess(y_pred_nifti, nii_img, labels_mapping, save_path=save_path, verbose=False)
                final_mask = processor.deprocess(y_pred_mask_nifti, nii_img, labels_mapping, save_path=mask_save_path, verbose=False)
                estimate_volume(final_image, resolution=patch_resolution, verbose=True)
                
                print ('----------------------------------------------------------// \n\n')

    # save an excel file with the volumes
    save_excel_table(os.path.join(dataset_folder, modality_folder), sub_folder=folder, include_only_list=None, save_folder=os.path.join(save_folder, modality_folder),
                    pred_roi_name=roi_prediction_postfix, pred_brain_name=brain_prediction_postfix, name_mapping=name_mapping, file_name=excel_name, postfix_mode=True)
# Out:
# |- TBI_PNRR_BATMAN_fp_24_101_anat_orig.nii.gz -------------------\
#
# Number of classes:  5
#
# - Classes present in the mask:  [ 0.  1.  3. 13. 21.]
# Class 0.0 has 2616737 voxels and a volume of 2616.7370000000005 mm^3
# Class 1.0 has 19191 voxels and a volume of 19.191000000000003 mm^3
# Class 3.0 has 1770 voxels and a volume of 1.77 mm^3
# Class 13.0 has 613 voxels and a volume of 0.6130000000000001 mm^3
# Class 21.0 has 1689 voxels and a volume of 1.689 mm^3
# ----------------------------------------------------------//
#
#
#
# |- TBI_PNRR_BATMAN_fp_24_102_anat_orig.nii.gz -------------------\
#
# Number of classes:  5
#
# - Classes present in the mask:  [ 0.  1.  3. 13. 21.]
# Class 0.0 has 2619307 voxels and a volume of 2619.3070000000007 mm^3
# Class 1.0 has 14835 voxels and a volume of 14.835 mm^3
# Class 3.0 has 3163 voxels and a volume of 3.1630000000000003 mm^3
# Class 13.0 has 687 voxels and a volume of 0.6870000000000002 mm^3
# Class 21.0 has 2008 voxels and a volume of 2.0080000000000005 mm^3
# ----------------------------------------------------------//
#
#
#
# |- TBI_PNRR_BATMAN_fp_24_104_anat_orig.nii.gz -------------------\
#
# Number of classes:  5
#
# - Classes present in the mask:  [ 0.  1.  3. 13. 21.]
# Class 0.0 has 2620669 voxels and a volume of 2620.6690000000003 mm^3
# Class 1.0 has 14688 voxels and a volume of 14.688000000000002 mm^3
# Class 3.0 has 1998 voxels and a volume of 1.9980000000000004 mm^3
# Class 13.0 has 946 voxels and a volume of 0.9460000000000002 mm^3
# Class 21.0 has 1699 voxels and a volume of 1.6990000000000003 mm^3
# ----------------------------------------------------------//
#
#
#
# |- TBI_PNRR_BATMAN_fp_24_105_anat_orig.nii.gz -------------------\
#
# Number of classes:  5
#
# - Classes present in the mask:  [ 0.  1.  3. 13. 21.]
# Class 0.0 has 2621477 voxels and a volume of 2621.4770000000008 mm^3
# Class 1.0 has 13452 voxels and a volume of 13.452000000000002 mm^3
# Class 3.0 has 2775 voxels and a volume of 2.7750000000000004 mm^3
# Class 13.0 has 826 voxels and a volume of 0.8260000000000002 mm^3
# Class 21.0 has 1470 voxels and a volume of 1.4700000000000002 mm^3
# ----------------------------------------------------------//
#
#
#
# |- TBI_PNRR_BATMAN_fp_24_106_anat_orig.nii.gz -------------------\
#
# Number of classes:  5
#
# - Classes present in the mask:  [ 0.  1.  3. 13. 21.]
# Class 0.0 has 2619909 voxels and a volume of 2619.9090000000006 mm^3
# Class 1.0 has 14086 voxels and a volume of 14.086000000000002 mm^3
# Class 3.0 has 3165 voxels and a volume of 3.1650000000000005 mm^3
# Class 13.0 has 810 voxels and a volume of 0.81 mm^3
# Class 21.0 has 2030 voxels and a volume of 2.0300000000000002 mm^3
# ----------------------------------------------------------//
#
#
#
# |- TBI_PNRR_BATMAN_fp_24_107_anat_orig.nii.gz -------------------\
#
# Number of classes:  5
#
# - Classes present in the mask:  [ 0.  1.  3. 13. 21.]
# Class 0.0 has 2627031 voxels and a volume of 2627.031000000001 mm^3
# Class 1.0 has 8846 voxels and a volume of 8.846000000000002 mm^3
# Class 3.0 has 1931 voxels and a volume of 1.9310000000000003 mm^3
# Class 13.0 has 872 voxels and a volume of 0.8720000000000001 mm^3
# Class 21.0 has 1320 voxels and a volume of 1.3200000000000003 mm^3
# ----------------------------------------------------------//
#
#
#
# |- TBI_PNRR_BATMAN_fp_24_108_anat_orig.nii.gz -------------------\
#
# Number of classes:  5
#
# - Classes present in the mask:  [ 0.  1.  3. 13. 21.]
# Class 0.0 has 2622279 voxels and a volume of 2622.2790000000005 mm^3
# Class 1.0 has 13163 voxels and a volume of 13.163000000000004 mm^3
# Class 3.0 has 2247 voxels and a volume of 2.2470000000000003 mm^3
# Class 13.0 has 768 voxels and a volume of 0.7680000000000002 mm^3
# Class 21.0 has 1543 voxels and a volume of 1.5430000000000001 mm^3
# ----------------------------------------------------------//
#
#
#
# |- TBI_PNRR_BATMAN_fp_24_109_anat_orig.nii.gz -------------------\
#
# Number of classes:  5
#
# - Classes present in the mask:  [ 0.  1.  3. 13. 21.]
# Class 0.0 has 2631704 voxels and a volume of 2631.7040000000006 mm^3
# Class 1.0 has 17 voxels and a volume of 0.017000000000000005 mm^3
# Class 3.0 has 3451 voxels and a volume of 3.4510000000000005 mm^3
# Class 13.0 has 3109 voxels and a volume of 3.1090000000000004 mm^3
# Class 21.0 has 1719 voxels and a volume of 1.7190000000000003 mm^3
# ----------------------------------------------------------//
#
#
#
# |- TBI_PNRR_BATMAN_fp_24_110_anat_orig.nii.gz -------------------\
#
# Number of classes:  5
#
# - Classes present in the mask:  [ 0.  1.  3. 13. 21.]
# Class 0.0 has 2615999 voxels and a volume of 2615.9990000000007 mm^3
# Class 1.0 has 17292 voxels and a volume of 17.292 mm^3
# Class 3.0 has 3265 voxels and a volume of 3.265 mm^3
# Class 13.0 has 988 voxels and a volume of 0.9880000000000003 mm^3
# Class 21.0 has 2456 voxels and a volume of 2.4560000000000004 mm^3
# ----------------------------------------------------------//
#
#
#
# |- TBI_PNRR_BATMAN_fp_24_111_anat_orig.nii.gz -------------------\
#
# Number of classes:  5
#
# - Classes present in the mask:  [ 0.  1.  3. 13. 21.]
# Class 0.0 has 2621277 voxels and a volume of 2621.2770000000005 mm^3
# Class 1.0 has 13837 voxels and a volume of 13.837000000000002 mm^3
# Class 3.0 has 2350 voxels and a volume of 2.35 mm^3
# Class 13.0 has 821 voxels and a volume of 0.8210000000000002 mm^3
# Class 21.0 has 1715 voxels and a volume of 1.7150000000000003 mm^3
# ----------------------------------------------------------//
#
#
#
# |- TBI_PNRR_BATMAN_fp_24_112_anat_orig.nii.gz -------------------\
#
# Number of classes:  5
#
# - Classes present in the mask:  [ 0.  1.  3. 13. 21.]
# Class 0.0 has 2617267 voxels and a volume of 2617.2670000000003 mm^3
# Class 1.0 has 17497 voxels and a volume of 17.497000000000003 mm^3
# Class 3.0 has 2759 voxels and a volume of 2.7590000000000003 mm^3
# Class 13.0 has 671 voxels and a volume of 0.6710000000000002 mm^3
# Class 21.0 has 1806 voxels and a volume of 1.8060000000000003 mm^3
# ----------------------------------------------------------//
#
#
#
# |- TBI_PNRR_BATMAN_fp_24_113_anat_orig.nii.gz -------------------\
#
# Number of classes:  5
#
# - Classes present in the mask:  [ 0.  1.  3. 13. 21.]
# Class 0.0 has 2619380 voxels and a volume of 2619.3800000000006 mm^3
# Class 1.0 has 16982 voxels and a volume of 16.982000000000003 mm^3
# Class 3.0 has 1854 voxels and a volume of 1.8540000000000003 mm^3
# Class 13.0 has 432 voxels and a volume of 0.43200000000000005 mm^3
# Class 21.0 has 1352 voxels and a volume of 1.3520000000000003 mm^3
# ----------------------------------------------------------//
#
#
#
# |- TBI_PNRR_BATMAN_fp_24_114_anat_orig.nii.gz -------------------\
#
# Number of classes:  5
#
# - Classes present in the mask:  [ 0.  1.  3. 13. 21.]
# Class 0.0 has 2605949 voxels and a volume of 2605.9490000000005 mm^3
# Class 1.0 has 26959 voxels and a volume of 26.959000000000003 mm^3
# Class 3.0 has 4505 voxels and a volume of 4.505000000000001 mm^3
# Class 13.0 has 830 voxels and a volume of 0.8300000000000001 mm^3
# Class 21.0 has 1757 voxels and a volume of 1.7570000000000006 mm^3
# ----------------------------------------------------------//
#
#
#
# |- TBI_PNRR_BATMAN_fp_24_115_anat_orig.nii.gz -------------------\
#
# Number of classes:  5
#
# - Classes present in the mask:  [ 0.  1.  3. 13. 21.]
# Class 0.0 has 2623948 voxels and a volume of 2623.9480000000003 mm^3
# Class 1.0 has 12246 voxels and a volume of 12.246000000000002 mm^3
# Class 3.0 has 1441 voxels and a volume of 1.441 mm^3
# Class 13.0 has 713 voxels and a volume of 0.7130000000000001 mm^3
# Class 21.0 has 1652 voxels and a volume of 1.6520000000000004 mm^3
# ----------------------------------------------------------//
#
#
#
# |- TBI_PNRR_BATMAN_fp_24_116_anat_orig.nii.gz -------------------\
#
# Number of classes:  5
#
# - Classes present in the mask:  [ 0.  1.  3. 13. 21.]
# Class 0.0 has 2617511 voxels and a volume of 2617.5110000000004 mm^3
# Class 1.0 has 16209 voxels and a volume of 16.209000000000003 mm^3
# Class 3.0 has 3559 voxels and a volume of 3.5590000000000006 mm^3
# Class 13.0 has 947 voxels and a volume of 0.9470000000000001 mm^3
# Class 21.0 has 1774 voxels and a volume of 1.7740000000000002 mm^3
# ----------------------------------------------------------//
#
#
#
# |- TBI_PNRR_BATMAN_fp_24_117_anat_orig.nii.gz -------------------\
#
# Number of classes:  4
#
# - Classes present in the mask:  [ 0.  3. 13. 21.]
# Class 0.0 has 2634523 voxels and a volume of 2634.523 mm^3
# Class 3.0 has 2180 voxels and a volume of 2.18 mm^3
# Class 13.0 has 1936 voxels and a volume of 1.9360000000000004 mm^3
# Class 21.0 has 1361 voxels and a volume of 1.361 mm^3
# ----------------------------------------------------------//
#
#
#
# |- TBI_PNRR_BATMAN_fp_24_118_anat_orig.nii.gz -------------------\
#
# Number of classes:  5
#
# - Classes present in the mask:  [ 0.  1.  3. 13. 21.]
# Class 0.0 has 2617453 voxels and a volume of 2617.4530000000004 mm^3
# Class 1.0 has 16982 voxels and a volume of 16.982000000000003 mm^3
# Class 3.0 has 2864 voxels and a volume of 2.8640000000000008 mm^3
# Class 13.0 has 822 voxels and a volume of 0.8220000000000001 mm^3
# Class 21.0 has 1879 voxels and a volume of 1.8790000000000004 mm^3
# ----------------------------------------------------------//
#
#
#
# |- TBI_PNRR_BATMAN_fp_24_119_anat_orig.nii.gz -------------------\
#
# Number of classes:  5
#
# - Classes present in the mask:  [ 0.  1.  3. 13. 21.]
# Class 0.0 has 2620228 voxels and a volume of 2620.2280000000005 mm^3
# Class 1.0 has 14263 voxels and a volume of 14.263000000000003 mm^3
# Class 3.0 has 3024 voxels and a volume of 3.024000000000001 mm^3
# Class 13.0 has 813 voxels and a volume of 0.8130000000000002 mm^3
# Class 21.0 has 1672 voxels and a volume of 1.6720000000000004 mm^3
# ----------------------------------------------------------//
#
#
#
# |- TBI_PNRR_BATMAN_fp_24_120_anat_orig.nii.gz -------------------\
#
# Number of classes:  5
#
# - Classes present in the mask:  [ 0.  1.  3. 13. 21.]
# Class 0.0 has 2622206 voxels and a volume of 2622.2060000000006 mm^3
# Class 1.0 has 13724 voxels and a volume of 13.724000000000002 mm^3
# Class 3.0 has 1538 voxels and a volume of 1.5380000000000003 mm^3
# Class 13.0 has 926 voxels and a volume of 0.9260000000000002 mm^3
# Class 21.0 has 1606 voxels and a volume of 1.6060000000000003 mm^3
# ----------------------------------------------------------//
#
#
#
# |- TBI_PNRR_BATMAN_fp_24_121_anat_orig.nii.gz -------------------\
#
# Number of classes:  5
#
# - Classes present in the mask:  [ 0.  1.  3. 13. 21.]
# Class 0.0 has 2616478 voxels and a volume of 2616.4780000000005 mm^3
# Class 1.0 has 18792 voxels and a volume of 18.792 mm^3
# Class 3.0 has 2132 voxels and a volume of 2.1320000000000006 mm^3
# Class 13.0 has 807 voxels and a volume of 0.807 mm^3
# Class 21.0 has 1791 voxels and a volume of 1.7910000000000004 mm^3
# ----------------------------------------------------------//
#
#
#
# |- TBI_PNRR_BATMAN_fp_24_122_anat_orig.nii.gz -------------------\
#
# Number of classes:  5
#
# - Classes present in the mask:  [ 0.  1.  3. 13. 21.]
# Class 0.0 has 2618139 voxels and a volume of 2618.1390000000006 mm^3
# Class 1.0 has 15355 voxels and a volume of 15.355000000000002 mm^3
# Class 3.0 has 3787 voxels and a volume of 3.787000000000001 mm^3
# Class 13.0 has 843 voxels and a volume of 0.8430000000000002 mm^3
# Class 21.0 has 1876 voxels and a volume of 1.8760000000000003 mm^3
# ----------------------------------------------------------//
#
#
#
# |- TBI_PNRR_BATMAN_fp_24_123_anat_orig.nii.gz -------------------\
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[14], line 38
#      35 x_prep = processor.preprocess(nii_img,  path=file_path)
#      37 # create a mask for this new unseen file
# ---> 38 results = predictor.random_cropping_inference(x_prep, with_brain_mask=True)
#      39 y_mask = results['brain_mask']
#      40 y_regions = results['roi']
#
# File c:\Users\fmoro\SegmentationProject\SegmentationThesis\src\evaluation\inference.py:109, in RandomCroppingPrediction.random_cropping_inference(self, input_img, with_brain_mask, with_classifier)
#     106 patch = self.extract_patch(input_volume, start, end)
#     107 predicted_patch, brain_patch, predicted_aux = self.perform_inference(patch, with_brain_mask, with_classifier)
# --> 109 self.update_prediction_arrays(predicted_patches, count_map, predicted_patch, start, end)
#     111 if with_brain_mask:
#     112     self.update_brain_arrays(predicted_brain_patches, brain_count_map, brain_patch, start, end)
#
# File c:\Users\fmoro\SegmentationProject\SegmentationThesis\src\evaluation\inference.py:170, in RandomCroppingPrediction.update_prediction_arrays(self, predicted_patches, count_map, predicted_patch, start, end)
#     168 for i in range(self.num_classes):
#     169     predicted_patches[start[0]:end[0], start[1]:end[1], start[2]:end[2], i] += predicted_patch[..., i]
# --> 170     count_map[start[0]:end[0], start[1]:end[1], start[2]:end[2], i] += 1
#
# KeyboardInterrupt:
