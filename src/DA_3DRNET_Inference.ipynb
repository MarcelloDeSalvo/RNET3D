# %% [markdown]
# # Domain Adaptation Predictions

# %% [markdown]
# ## Intro
# Given a list of nii.gz files inside a folder, makes a brain mask and a ROI mask prediction with a given loaded model

# %% [markdown]
# ## Libraries

# %%
# utils
from utils.utils import save_excel_table
from utils.nifti import estimate_volume

# visualization
from utils.vedo import plot_slicer_cloud, plot_volume_cloud

# neural imaging
import nibabel as nib

# tensorflow
import tensorflow as tf
from evaluation.metrics import *

# other
import os
import importlib
import numpy as np

# make numpy printouts easier to read.
np.set_printoptions(precision=3, suppress=True)
print("Num GPUs Available: ", len(tf.config.list_physical_devices('GPU')))
# Out:
# Num GPUs Available:  1

# %% [markdown]
# ## Configuration
# Here it's possible to change some paramaters to make predictions

# %% [markdown]
# Paths:
# - dataset_folder (string): path to the folder that contains the files on which we want to make predictions
# - save_folder (string): path to the folder in which we want to save the predictions

# %%
dataset_folder = r'I:\\DannoCerebraleAcuto_MRI\\EDA\\'
# dataset_folder = r'I:\\DannoCerebraleAcuto_MRI\\PNRR BATMAN Microbiota\\Exp SCFA\\'
save_folder = dataset_folder

# %% [markdown]
# Save results:
# - save (boolean): if true, saves the predictions in save_folder

# %%
save = True

# %% [markdown]
# 3D preview:
# - show_3d_preview (boolean): shows the predicted mask in an external window

# %%
show_3d_preview = False

# %% [markdown]
# Morphological smoothing:
# - remove_small_objects (boolean): if true, removes small unconnected regions based on object_min_area
# - object_min_area (int): the smallest allowable contiguos region size, in voxels
# - fill_small_holes (boolean): if true, fills small holes
# - holes_max_area (int): the maximum area, in voxels, of a contiguous hole that will be filled

# %%
remove_small_objects = True
object_min_area = 30000
fill_small_holes = True
holes_max_area = 20000

# %% [markdown]
# Prediction parameters:
# - patch_size (tuple): size of the sliding window used to extract patches from the image
# - patch_resolution (tuple): desired target resolution for all patch (should be equal to the training resolution of the model)
# - stride (int): translation offset of the sliding window (less is better but requires more computational time)
#
# Suggested stride values: 6,8,12,16

# %%
patch_size = (80,80,80) #voxels
patch_resolution = (0.1,0.1,0.1) #mm
stride = 10
threshold = 0.5

# %% [markdown]
# Input and output filenames:

# %%
# Input Image
input_postfix = '_anat_orig.nii.gz'

# Output Masks
brain_prediction_postfix = '_brain_mask_r3dnet.nii.gz'
roi_prediction_postfix = f'_regions_r3dnet_DA.nii.gz'

# Excel Table Name
excel_name = f'predicted_r3dnet_volumes_DA.xlsx'

# %% [markdown]
# To make a prediction, the program expects a standard folder structure similar to the following:
# ```python
# target_folder/
#   FLASH/
#     ID_MICE_A/
#       Anat/
#         ID_MICE_A_N4.nii.gz
#         ...
#     ID_MICE_B/
#       Anat/
#         ID_MICE_B_N4.nii.gz
#         ...
#   DTI/
#     ID_MICE_F/
#       dti/
#         ID_MICE_F_N4.nii.gz
#         ...
#   Other.../
# ```
# In this structure, there is a folder for each group of mice, such as `FLASH`, `RARE`, or `Group_1`.
#
# Inside each group folder, it is **strictly required** that each mouse file name starts with the same folder name as that of the mouse.
#
# For example, the `ID_MICE_A` folder should contain only files starting with `ID_MICE_A`. The subfolder (e.g., `Anat`) and the postfix file name extension (e.g., `N4`) can be modified later if needed.
#
# You can specify the modalities directories in the following variable:
#
# ```python
# modalities_directories = {
#     'FLASH': 'Anat',
#     'RARE': 'Anat',
#     'DTI': 'dti',
#     # Add more modalities as needed
# }
# ```

# %%
# Folder structure for structured mode
modalities_directories = {
    '1months': 'Anat',
}

# Output labels ( Network -> Output mask labels)
labels_mapping = {
    0: 0, #0
    1: 1, #1
    2: 2, #2
    3: 3, #3
    4: 5, #5
    5: 6, #6
    6: 12, #12
    7: 13, #13
    8: 15, #15
    9: 16, #16
    10: 21, #21
}


# - Background (label 0)
# - Lesion (red, label 1)
# - CC contra (green, label 2)
# - CC ipsi (dark blue, label 12)
# - Ventricle contra (blue, label 3)
# - Ventricle ipsi (light green, label 13)
# - Hippo contra (cyan, label 5)
# - Hippo ipsi (light brown, label 15)
# - Cortex contra (pink, label 6)
# - Cortex ispi (light blue, label 16)
# - Third Ventricle (purple, label 21)
name_mapping = {
    0: {'name': 'Background', 'value': 0},
    1: {'name': 'Lesion', 'value': 1},
    2: {'name': 'Contra CC', 'value': 2},
    3: {'name': 'Ipsi CC', 'value': 12},
    4: {'name': 'Contra Ventricle', 'value': 3},
    5: {'name': 'Ipsi Ventricle', 'value': 13},
    6: {'name': 'Contra Hippo', 'value': 5},
    7: {'name': 'Ipsi Hippo', 'value': 15},
    8: {'name': 'Contra Cortex', 'value': 6},
    9: {'name': 'Ipsi Cortex', 'value': 16},
    10: {'name': 'Third Ventricle', 'value': 21},
}

num_classes = len(labels_mapping)

# %% [markdown]
# From here the code should remain unchanged

# %%
input_channels = 1

# MODEL_NAME = 'mice_roi_unet_ep500_18-05-2024_13-25' # Alzato std random cropping
# MODEL_NAME = 'mice_roi_unet_ep500_18-05-2024_21-53' # Domain split attention
# MODEL_NAME = 'mice_roi_unet_ep500_19-05-2024_03-45' # Attention 2.0
# MODEL_NAME = 'mice_roi_unet_ep500_19-05-2024_14-35' # Attention 2.0 + old losses
# MODEL_NAME = 'mice_roi_unet_ep500_19-05-2024_17-08' # Attention 2.0 + 2x sampling (no miss)
# MODEL_NAME = 'mice_roi_unet_ep500_19-05-2024_23-18' # 2x sampling (miss)
# MODEL_NAME = 'mice_roi_unet_ep500_20-05-2024_00-53' # 2x sampling 
# MODEL_NAME = 'mice_roi_unet_ep500_20-05-2024_18-46' # 2x sampling + no classificator (check this out)
# MODEL_NAME = 'mice_roi_unet_ep500_21-05-2024_02-35' # 2x sampling + more dense neuons
# MODEL_NAME = 'mice_roi_unet_ep500_21-05-2024_14-06' # 2x sampling + deeper network
# MODEL_NAME = 'mice_roi_unet_ep500_22-05-2024_11-58' # 2x sampling + deeper network 




MODEL_NAME = 'mice_roi_unet_ep500_29-06-2024_01-22' # final model

MODEL_NAME = 'mice_roi_unet_ep500_22-05-2024_15-25' # 2x sampling + deeper network + domain attention best so far
MODEL_NAME = 'rnet_da.h5'
MODEL_NAME = 'mice_da_unet_ep500_03-03-2025_23-59'
full_name = 'model_fold_0.h5'
full_name = 'save_' + MODEL_NAME + '.h5'

model_path = '../models/' + MODEL_NAME 
model_path = '../results/' + MODEL_NAME + '/' + full_name

# %%
process_id = None

# %% [markdown]
# ## Load the model
# Load a previously trained model to start making predictions

# %%
import models.networks
from evaluation.metrics import *
from evaluation.losses import *

model = tf.keras.models.load_model(model_path,
                                   custom_objects={ "loss": diceCELoss(),
                                                    "precision": precision_coefficient(),
                                                    "sensitivity": sensitivity_coefficient(),
                                                    "specificity": specificity_coefficient(),
                                                    "K": tf.keras.backend,
                                                    "training": False,
                                                  }, compile=False)

model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, None, None,  0           []
#                                  None, 1)]
#
#  conv3d_10 (Conv3D)             (None, None, None,   448         ['input_1[0][0]']
#                                 None, 16)
#
#  batch_normalization_6 (BatchNo  (None, None, None,   64         ['conv3d_10[0][0]']
#  rmalization)                   None, 16)
#
#  average_pooling3d (AveragePool  (None, None, None,   0          ['input_1[0][0]']
#  ing3D)                         None, 1)
#
#  conv3d_11 (Conv3D)             (None, None, None,   6928        ['batch_normalization_6[0][0]']
#                                 None, 16)
#
#  conv3d_1 (Conv3D)              (None, None, None,   896         ['average_pooling3d[0][0]']
#                                 None, 32)
#
#  batch_normalization_7 (BatchNo  (None, None, None,   64         ['conv3d_11[0][0]']
#  rmalization)                   None, 16)
#
#  conv3d_9 (Conv3D)              (None, None, None,   32          ['input_1[0][0]']
#                                 None, 16)
#
#  batch_normalization (BatchNorm  (None, None, None,   128        ['conv3d_1[0][0]']
#  alization)                     None, 32)
#
#  add_3 (Add)                    (None, None, None,   0           ['batch_normalization_7[0][0]',
#                                 None, 16)                         'conv3d_9[0][0]']
#
#  conv3d_2 (Conv3D)              (None, None, None,   27680       ['batch_normalization[0][0]']
#                                 None, 32)
#
#  activation_3 (Activation)      (None, None, None,   0           ['add_3[0][0]']
#                                 None, 16)
#
#  batch_normalization_1 (BatchNo  (None, None, None,   128        ['conv3d_2[0][0]']
#  rmalization)                   None, 32)
#
#  conv3d (Conv3D)                (None, None, None,   64          ['average_pooling3d[0][0]']
#                                 None, 32)
#
#  max_pooling3d (MaxPooling3D)   (None, None, None,   0           ['activation_3[0][0]']
#                                 None, 16)
#
#  add (Add)                      (None, None, None,   0           ['batch_normalization_1[0][0]',
#                                 None, 32)                         'conv3d[0][0]']
#
#  spatial_dropout3d (SpatialDrop  (None, None, None,   0          ['max_pooling3d[0][0]']
#  out3D)                         None, 16)
#
#  activation (Activation)        (None, None, None,   0           ['add[0][0]']
#                                 None, 32)
#
#  concatenate (Concatenate)      (None, None, None,   0           ['spatial_dropout3d[0][0]',
#                                 None, 48)                         'activation[0][0]']
#
#  conv3d_13 (Conv3D)             (None, None, None,   41504       ['concatenate[0][0]']
#                                 None, 32)
#
#  batch_normalization_8 (BatchNo  (None, None, None,   128        ['conv3d_13[0][0]']
#  rmalization)                   None, 32)
#
#  average_pooling3d_1 (AveragePo  (None, None, None,   0          ['average_pooling3d[0][0]']
#  oling3D)                       None, 1)
#
#  conv3d_14 (Conv3D)             (None, None, None,   27680       ['batch_normalization_8[0][0]']
#                                 None, 32)
#
#  conv3d_4 (Conv3D)              (None, None, None,   1792        ['average_pooling3d_1[0][0]']
#                                 None, 64)
#
#  batch_normalization_9 (BatchNo  (None, None, None,   128        ['conv3d_14[0][0]']
#  rmalization)                   None, 32)
#
#  conv3d_12 (Conv3D)             (None, None, None,   1568        ['concatenate[0][0]']
#                                 None, 32)
#
#  batch_normalization_2 (BatchNo  (None, None, None,   256        ['conv3d_4[0][0]']
#  rmalization)                   None, 64)
#
#  add_4 (Add)                    (None, None, None,   0           ['batch_normalization_9[0][0]',
#                                 None, 32)                         'conv3d_12[0][0]']
#
#  conv3d_5 (Conv3D)              (None, None, None,   110656      ['batch_normalization_2[0][0]']
#                                 None, 64)
#
#  activation_4 (Activation)      (None, None, None,   0           ['add_4[0][0]']
#                                 None, 32)
#
#  batch_normalization_3 (BatchNo  (None, None, None,   256        ['conv3d_5[0][0]']
#  rmalization)                   None, 64)
#
#  conv3d_3 (Conv3D)              (None, None, None,   128         ['average_pooling3d_1[0][0]']
#                                 None, 64)
#
#  max_pooling3d_1 (MaxPooling3D)  (None, None, None,   0          ['activation_4[0][0]']
#                                 None, 32)
#
#  add_1 (Add)                    (None, None, None,   0           ['batch_normalization_3[0][0]',
#                                 None, 64)                         'conv3d_3[0][0]']
#
#  spatial_dropout3d_1 (SpatialDr  (None, None, None,   0          ['max_pooling3d_1[0][0]']
#  opout3D)                       None, 32)
#
#  activation_1 (Activation)      (None, None, None,   0           ['add_1[0][0]']
#                                 None, 64)
#
#  concatenate_1 (Concatenate)    (None, None, None,   0           ['spatial_dropout3d_1[0][0]',
#                                 None, 96)                         'activation_1[0][0]']
#
#  conv3d_16 (Conv3D)             (None, None, None,   165952      ['concatenate_1[0][0]']
#                                 None, 64)
#
#  batch_normalization_10 (BatchN  (None, None, None,   256        ['conv3d_16[0][0]']
#  ormalization)                  None, 64)
#
#  average_pooling3d_2 (AveragePo  (None, None, None,   0          ['average_pooling3d_1[0][0]']
#  oling3D)                       None, 1)
#
#  conv3d_17 (Conv3D)             (None, None, None,   110656      ['batch_normalization_10[0][0]']
#                                 None, 64)
#
#  conv3d_7 (Conv3D)              (None, None, None,   3584        ['average_pooling3d_2[0][0]']
#                                 None, 128)
#
#  batch_normalization_11 (BatchN  (None, None, None,   256        ['conv3d_17[0][0]']
#  ormalization)                  None, 64)
#
#  conv3d_15 (Conv3D)             (None, None, None,   6208        ['concatenate_1[0][0]']
#                                 None, 64)
#
#  batch_normalization_4 (BatchNo  (None, None, None,   512        ['conv3d_7[0][0]']
#  rmalization)                   None, 128)
#
#  add_5 (Add)                    (None, None, None,   0           ['batch_normalization_11[0][0]',
#                                 None, 64)                         'conv3d_15[0][0]']
#
#  conv3d_8 (Conv3D)              (None, None, None,   442496      ['batch_normalization_4[0][0]']
#                                 None, 128)
#
#  activation_5 (Activation)      (None, None, None,   0           ['add_5[0][0]']
#                                 None, 64)
#
#  batch_normalization_5 (BatchNo  (None, None, None,   512        ['conv3d_8[0][0]']
#  rmalization)                   None, 128)
#
#  conv3d_6 (Conv3D)              (None, None, None,   256         ['average_pooling3d_2[0][0]']
#                                 None, 128)
#
#  max_pooling3d_2 (MaxPooling3D)  (None, None, None,   0          ['activation_5[0][0]']
#                                 None, 64)
#
#  add_2 (Add)                    (None, None, None,   0           ['batch_normalization_5[0][0]',
#                                 None, 128)                        'conv3d_6[0][0]']
#
#  spatial_dropout3d_2 (SpatialDr  (None, None, None,   0          ['max_pooling3d_2[0][0]']
#  opout3D)                       None, 64)
#
#  activation_2 (Activation)      (None, None, None,   0           ['add_2[0][0]']
#                                 None, 128)
#
#  concatenate_2 (Concatenate)    (None, None, None,   0           ['spatial_dropout3d_2[0][0]',
#                                 None, 192)                        'activation_2[0][0]']
#
#  conv3d_19 (Conv3D)             (None, None, None,   663680      ['concatenate_2[0][0]']
#                                 None, 128)
#
#  batch_normalization_12 (BatchN  (None, None, None,   512        ['conv3d_19[0][0]']
#  ormalization)                  None, 128)
#
#  conv3d_20 (Conv3D)             (None, None, None,   442496      ['batch_normalization_12[0][0]']
#                                 None, 128)
#
#  batch_normalization_13 (BatchN  (None, None, None,   512        ['conv3d_20[0][0]']
#  ormalization)                  None, 128)
#
#  conv3d_18 (Conv3D)             (None, None, None,   24704       ['concatenate_2[0][0]']
#                                 None, 128)
#
#  add_6 (Add)                    (None, None, None,   0           ['batch_normalization_13[0][0]',
#                                 None, 128)                        'conv3d_18[0][0]']
#
#  activation_6 (Activation)      (None, None, None,   0           ['add_6[0][0]']
#                                 None, 128)
#
#  max_pooling3d_3 (MaxPooling3D)  (None, None, None,   0          ['activation_6[0][0]']
#                                 None, 128)
#
#  spatial_dropout3d_3 (SpatialDr  (None, None, None,   0          ['max_pooling3d_3[0][0]']
#  opout3D)                       None, 128)
#
#  conv3d_22 (Conv3D)             (None, None, None,   884992      ['spatial_dropout3d_3[0][0]']
#                                 None, 256)
#
#  batch_normalization_14 (BatchN  (None, None, None,   1024       ['conv3d_22[0][0]']
#  ormalization)                  None, 256)
#
#  conv3d_23 (Conv3D)             (None, None, None,   1769728     ['batch_normalization_14[0][0]']
#                                 None, 256)
#
#  batch_normalization_15 (BatchN  (None, None, None,   1024       ['conv3d_23[0][0]']
#  ormalization)                  None, 256)
#
#  conv3d_21 (Conv3D)             (None, None, None,   33024       ['spatial_dropout3d_3[0][0]']
#                                 None, 256)
#
#  add_7 (Add)                    (None, None, None,   0           ['batch_normalization_15[0][0]',
#                                 None, 256)                        'conv3d_21[0][0]']
#
#  activation_7 (Activation)      (None, None, None,   0           ['add_7[0][0]']
#                                 None, 256)
#
#  conv3d_transpose (Conv3DTransp  (None, None, None,   262272     ['activation_7[0][0]']
#  ose)                           None, 128)
#
#  batch_normalization_16 (BatchN  (None, None, None,   512        ['conv3d_transpose[0][0]']
#  ormalization)                  None, 128)
#
#  concatenate_3 (Concatenate)    (None, None, None,   0           ['batch_normalization_16[0][0]',
#                                 None, 256)                        'activation_6[0][0]']
#
#  conv3d_25 (Conv3D)             (None, None, None,   884864      ['concatenate_3[0][0]']
#                                 None, 128)
#
#  batch_normalization_17 (BatchN  (None, None, None,   512        ['conv3d_25[0][0]']
#  ormalization)                  None, 128)
#
#  conv3d_26 (Conv3D)             (None, None, None,   442496      ['batch_normalization_17[0][0]']
#                                 None, 128)
#
#  batch_normalization_18 (BatchN  (None, None, None,   512        ['conv3d_26[0][0]']
#  ormalization)                  None, 128)
#
#  conv3d_24 (Conv3D)             (None, None, None,   32896       ['concatenate_3[0][0]']
#                                 None, 128)
#
#  add_8 (Add)                    (None, None, None,   0           ['batch_normalization_18[0][0]',
#                                 None, 128)                        'conv3d_24[0][0]']
#
#  activation_8 (Activation)      (None, None, None,   0           ['add_8[0][0]']
#                                 None, 128)
#
#  conv3d_transpose_1 (Conv3DTran  (None, None, None,   65600      ['activation_8[0][0]']
#  spose)                         None, 64)
#
#  batch_normalization_19 (BatchN  (None, None, None,   256        ['conv3d_transpose_1[0][0]']
#  ormalization)                  None, 64)
#
#  concatenate_4 (Concatenate)    (None, None, None,   0           ['batch_normalization_19[0][0]',
#                                 None, 128)                        'activation_5[0][0]']
#
#  conv3d_28 (Conv3D)             (None, None, None,   221248      ['concatenate_4[0][0]']
#                                 None, 64)
#
#  batch_normalization_20 (BatchN  (None, None, None,   256        ['conv3d_28[0][0]']
#  ormalization)                  None, 64)
#
#  conv3d_29 (Conv3D)             (None, None, None,   110656      ['batch_normalization_20[0][0]']
#                                 None, 64)
#
#  batch_normalization_21 (BatchN  (None, None, None,   256        ['conv3d_29[0][0]']
#  ormalization)                  None, 64)
#
#  conv3d_27 (Conv3D)             (None, None, None,   8256        ['concatenate_4[0][0]']
#                                 None, 64)
#
#  add_9 (Add)                    (None, None, None,   0           ['batch_normalization_21[0][0]',
#                                 None, 64)                         'conv3d_27[0][0]']
#
#  activation_9 (Activation)      (None, None, None,   0           ['add_9[0][0]']
#                                 None, 64)
#
#  conv3d_transpose_2 (Conv3DTran  (None, None, None,   16416      ['activation_9[0][0]']
#  spose)                         None, 32)
#
#  batch_normalization_22 (BatchN  (None, None, None,   128        ['conv3d_transpose_2[0][0]']
#  ormalization)                  None, 32)
#
#  concatenate_5 (Concatenate)    (None, None, None,   0           ['batch_normalization_22[0][0]',
#                                 None, 64)                         'activation_4[0][0]']
#
#  conv3d_31 (Conv3D)             (None, None, None,   55328       ['concatenate_5[0][0]']
#                                 None, 32)
#
#  batch_normalization_23 (BatchN  (None, None, None,   128        ['conv3d_31[0][0]']
#  ormalization)                  None, 32)
#
#  conv3d_32 (Conv3D)             (None, None, None,   27680       ['batch_normalization_23[0][0]']
#                                 None, 32)
#
#  batch_normalization_24 (BatchN  (None, None, None,   128        ['conv3d_32[0][0]']
#  ormalization)                  None, 32)
#
#  conv3d_30 (Conv3D)             (None, None, None,   2080        ['concatenate_5[0][0]']
#                                 None, 32)
#
#  add_10 (Add)                   (None, None, None,   0           ['batch_normalization_24[0][0]',
#                                 None, 32)                         'conv3d_30[0][0]']
#
#  activation_10 (Activation)     (None, None, None,   0           ['add_10[0][0]']
#                                 None, 32)
#
#  conv3d_transpose_3 (Conv3DTran  (None, None, None,   4112       ['activation_10[0][0]']
#  spose)                         None, 16)
#
#  batch_normalization_25 (BatchN  (None, None, None,   64         ['conv3d_transpose_3[0][0]']
#  ormalization)                  None, 16)
#
#  concatenate_6 (Concatenate)    (None, None, None,   0           ['batch_normalization_25[0][0]',
#                                 None, 32)                         'activation_3[0][0]']
#
#  conv3d_34 (Conv3D)             (None, None, None,   13840       ['concatenate_6[0][0]']
#                                 None, 16)
#
#  batch_normalization_26 (BatchN  (None, None, None,   64         ['conv3d_34[0][0]']
#  ormalization)                  None, 16)
#
#  conv3d_35 (Conv3D)             (None, None, None,   6928        ['batch_normalization_26[0][0]']
#                                 None, 16)
#
#  batch_normalization_27 (BatchN  (None, None, None,   64         ['conv3d_35[0][0]']
#  ormalization)                  None, 16)
#
#  conv3d_33 (Conv3D)             (None, None, None,   528         ['concatenate_6[0][0]']
#                                 None, 16)
#
#  add_11 (Add)                   (None, None, None,   0           ['batch_normalization_27[0][0]',
#                                 None, 16)                         'conv3d_33[0][0]']
#
#  global_average_pooling3d (Glob  (None, 256)         0           ['activation_7[0][0]']
#  alAveragePooling3D)
#
#  r_output_4 (Conv3D)            (None, None, None,   1419        ['activation_8[0][0]']
#                                 None, 11)
#
#  r_output_3 (Conv3D)            (None, None, None,   715         ['activation_9[0][0]']
#                                 None, 11)
#
#  r_output_2 (Conv3D)            (None, None, None,   363         ['activation_10[0][0]']
#                                 None, 11)
#
#  activation_11 (Activation)     (None, None, None,   0           ['add_11[0][0]']
#                                 None, 16)
#
#  b_output_4 (Conv3D)            (None, None, None,   129         ['activation_8[0][0]']
#                                 None, 1)
#
#  b_output_3 (Conv3D)            (None, None, None,   65          ['activation_9[0][0]']
#                                 None, 1)
#
#  b_output_2 (Conv3D)            (None, None, None,   33          ['activation_10[0][0]']
#                                 None, 1)
#
#  dense (Dense)                  (None, 512)          131584      ['global_average_pooling3d[0][0]'
#                                                                  ]
#
#  up_sampling3d_3 (UpSampling3D)  (None, None, None,   0          ['r_output_4[0][0]']
#                                 None, 11)
#
#  up_sampling3d_4 (UpSampling3D)  (None, None, None,   0          ['r_output_3[0][0]']
#                                 None, 11)
#
#  up_sampling3d_5 (UpSampling3D)  (None, None, None,   0          ['r_output_2[0][0]']
#                                 None, 11)
#
#  r_output_1 (Conv3D)            (None, None, None,   187         ['activation_11[0][0]']
#                                 None, 11)
#
#  up_sampling3d (UpSampling3D)   (None, None, None,   0           ['b_output_4[0][0]']
#                                 None, 1)
#
#  up_sampling3d_1 (UpSampling3D)  (None, None, None,   0          ['b_output_3[0][0]']
#                                 None, 1)
#
#  up_sampling3d_2 (UpSampling3D)  (None, None, None,   0          ['b_output_2[0][0]']
#                                 None, 1)
#
#  b_output_1 (Conv3D)            (None, None, None,   17          ['activation_11[0][0]']
#                                 None, 1)
#
#  dropout (Dropout)              (None, 512)          0           ['dense[0][0]']
#
#  add_13 (Add)                   (None, None, None,   0           ['up_sampling3d_3[0][0]',
#                                 None, 11)                         'up_sampling3d_4[0][0]',
#                                                                   'up_sampling3d_5[0][0]',
#                                                                   'r_output_1[0][0]']
#
#  add_12 (Add)                   (None, None, None,   0           ['up_sampling3d[0][0]',
#                                 None, 1)                          'up_sampling3d_1[0][0]',
#                                                                   'up_sampling3d_2[0][0]',
#                                                                   'b_output_1[0][0]']
#
#  dense_1 (Dense)                (None, 256)          131328      ['dropout[0][0]']
#
#  conv3d_37 (Conv3D)             (None, None, None,   132         ['add_13[0][0]']
#                                 None, 11)
#
#  conv3d_36 (Conv3D)             (None, None, None,   2           ['add_12[0][0]']
#                                 None, 1)
#
#  dropout_1 (Dropout)            (None, 256)          0           ['dense_1[0][0]']
#
#  regions (Activation)           (None, None, None,   0           ['conv3d_37[0][0]']
#                                 None, 11)
#
#  brain_mask (Activation)        (None, None, None,   0           ['conv3d_36[0][0]']
#                                 None, 1)
#
#  classifier (Dense)             (None, 1)            257         ['dropout_1[0][0]']
#
# ==================================================================================================
# Total params: 7,197,223
# Trainable params: 7,192,903
# Non-trainable params: 4,320
# __________________________________________________________________________________________________

# %% [markdown]
# ## Preprocessing configuration
# The standard pipeline order is:
# 1. (opt.) Cut and pad the image to a default matrix dimension
# 2. (opt.) Correct x10 intensity values
# 3. Apply N4 Bias Field correction
# 4. Copy the orientation from the ref. image
# 5. Resample to a target resolution
# 6. Normalize the intensity values with z-score (default)

# %%
from preprocessing.preprocessor import Preprocessor, Resample, Reorient, Normalize, CorrectX10, N4BiasFieldCorrection, SaveNifti

# ref image for reorientation
ref_img = nib.load(os.path.join('../example', 'RARE', 'TBI_fm_19_49', 'Anat', 'TBI_fm_19_49_N4.nii.gz'))

# Create an instance of the MRIProcessor class
processor = Preprocessor([
    CorrectX10(),
    N4BiasFieldCorrection(),
    SaveNifti(postfix='_N4', replace=input_postfix),
    Reorient(ref_img),
    Resample(target_resolution=patch_resolution, interpolation=0),
    Normalize()
])

# %% [markdown]
# ## Final Inference for random cropping
# Makes the predictions by sliding through the input a patch volume of size (80,80,80) with a stridde of 20

# %%
from evaluation.inference import RandomCroppingPrediction

# Create an instance of the RandomCroppingPrediction class
predictor = RandomCroppingPrediction(model, patch_size=patch_size, stride=stride, threshold=threshold, num_classes=num_classes)

# %% [markdown]
# Make predictions for every file inside the folder

# %%
import evaluation.postprocessing
importlib.reload(evaluation.postprocessing)
from evaluation.postprocessing import morphology_refinement_callback


for modality, folder in modalities_directories.items():

    # if modalities folder does not exist, skip
    if not os.path.isdir(os.path.join(dataset_folder, modality)): 
        print(f'Folder {folder} not found, skipping')
        continue

    modality_folder = os.path.join(dataset_folder, modality)

    for case in os.listdir(modality_folder):

        # if not dir skip
        if not os.path.isdir(os.path.join(modality_folder, case)): continue
        
        # If case substring is not in the process_id list, skip
        if process_id and case not in process_id: continue
        
        if not os.path.isdir(os.path.join(modality_folder, case, folder)): print(f'Folder {folder} not found, skipping'); continue
        case_folder = os.path.join(modality_folder, case, folder)

        for file in os.listdir(case_folder):
            if file == case + input_postfix:
                print('\n|-',file, '-------------------\ \n')
                file_path = os.path.join(case_folder, file)
                
                # load image
                nii_img = nib.load(os.path.join(case_folder, file))

                # preprocess image
                x_prep = processor.preprocess(nii_img,  path=file_path)

                # create a mask for this new unseen file
                results = predictor.random_cropping_inference(x_prep, with_brain_mask=True)
                y_mask = results['brain_mask']
                y_regions = results['roi']

                # postprocessing
                y_mask = morphology_refinement_callback(fill_small_holes=fill_small_holes, holes_max_area=holes_max_area,remove_small_objects=remove_small_objects, object_min_area=object_min_area)(y_mask)

                # save
                y_pred_nifti = nib.Nifti1Image(y_regions, affine=x_prep.affine, dtype=np.float64, header=x_prep.header)
                y_pred_mask_nifti = nib.Nifti1Image(y_mask, affine=x_prep.affine, dtype=np.float64, header=x_prep.header)

                if show_3d_preview: plot_slicer_cloud(x_prep, y_pred_nifti)

                # return to original shape and resolution
                save_path = os.path.join(save_folder, modality, case, folder, case + roi_prediction_postfix)
                mask_save_path = os.path.join(save_folder, modality, case, folder, case + brain_prediction_postfix)
                final_image = processor.deprocess(y_pred_nifti, nii_img, labels_mapping, save_path=save_path, verbose=False)
                #final_mask = processor.deprocess(y_pred_mask_nifti, nii_img, labels_mapping, save_path=mask_save_path, verbose=False)
                estimate_volume(final_image, resolution=patch_resolution, verbose=True)
                
                print ('----------------------------------------------------------// \n\n')

    # save an excel file with the volumes
    save_excel_table(os.path.join(dataset_folder, modality_folder), sub_folder=folder, include_only_list=None, save_folder=os.path.join(save_folder, modality_folder),
                    pred_roi_name=roi_prediction_postfix, pred_brain_name=brain_prediction_postfix, name_mapping=name_mapping, file_name=excel_name, postfix_mode=True)
# Out:
# |- TBI_EDA_ll_24_01_anat_orig.nii.gz -------------------\
#
# Number of classes:  11
#
# - Classes present in the mask:  [ 0.  1.  2.  3.  5.  6. 12. 13. 15. 16. 21.]
# Class 0.0 has 586479 voxels and a volume of 586.4790000000002 mm^3
# Class 1.0 has 6531 voxels and a volume of 6.531000000000001 mm^3
# Class 2.0 has 1948 voxels and a volume of 1.9480000000000004 mm^3
# Class 3.0 has 1039 voxels and a volume of 1.0390000000000001 mm^3
# Class 5.0 has 3288 voxels and a volume of 3.2880000000000003 mm^3
# Class 6.0 has 16272 voxels and a volume of 16.272000000000002 mm^3
# Class 12.0 has 546 voxels and a volume of 0.5460000000000002 mm^3
# Class 13.0 has 245 voxels and a volume of 0.24500000000000002 mm^3
# Class 15.0 has 1575 voxels and a volume of 1.5750000000000002 mm^3
# Class 16.0 has 11506 voxels and a volume of 11.506000000000002 mm^3
# Class 21.0 has 571 voxels and a volume of 0.5710000000000001 mm^3
# ----------------------------------------------------------//
#
#
#
# |- TBI_EDA_ll_24_02_anat_orig.nii.gz -------------------\
#
# Number of classes:  11
#
# - Classes present in the mask:  [ 0.  1.  2.  3.  5.  6. 12. 13. 15. 16. 21.]
# Class 0.0 has 587639 voxels and a volume of 587.639 mm^3
# Class 1.0 has 4557 voxels and a volume of 4.557000000000001 mm^3
# Class 2.0 has 1656 voxels and a volume of 1.6560000000000004 mm^3
# Class 3.0 has 1048 voxels and a volume of 1.0480000000000003 mm^3
# Class 5.0 has 3451 voxels and a volume of 3.4510000000000005 mm^3
# Class 6.0 has 16468 voxels and a volume of 16.468000000000004 mm^3
# Class 12.0 has 711 voxels and a volume of 0.7110000000000002 mm^3
# Class 13.0 has 385 voxels and a volume of 0.385 mm^3
# Class 15.0 has 1309 voxels and a volume of 1.3090000000000002 mm^3
# Class 16.0 has 12223 voxels and a volume of 12.223 mm^3
# Class 21.0 has 553 voxels and a volume of 0.5530000000000002 mm^3
# ----------------------------------------------------------//
#
#
#
# |- TBI_EDA_ll_24_03_anat_orig.nii.gz -------------------\
#
# Number of classes:  11
#
# - Classes present in the mask:  [ 0.  1.  2.  3.  5.  6. 12. 13. 15. 16. 21.]
# Class 0.0 has 587615 voxels and a volume of 587.6150000000001 mm^3
# Class 1.0 has 4187 voxels and a volume of 4.187 mm^3
# Class 2.0 has 1684 voxels and a volume of 1.6840000000000002 mm^3
# Class 3.0 has 1343 voxels and a volume of 1.3430000000000002 mm^3
# Class 5.0 has 3475 voxels and a volume of 3.475 mm^3
# Class 6.0 has 15819 voxels and a volume of 15.819000000000003 mm^3
# Class 12.0 has 628 voxels and a volume of 0.6280000000000001 mm^3
# Class 13.0 has 294 voxels and a volume of 0.29400000000000004 mm^3
# Class 15.0 has 1612 voxels and a volume of 1.612 mm^3
# Class 16.0 has 12842 voxels and a volume of 12.842000000000002 mm^3
# Class 21.0 has 501 voxels and a volume of 0.5010000000000001 mm^3
# ----------------------------------------------------------//
#
#
#
# |- TBI_EDA_ll_24_04_anat_orig.nii.gz -------------------\
#
# Number of classes:  11
#
# - Classes present in the mask:  [ 0.  1.  2.  3.  5.  6. 12. 13. 15. 16. 21.]
# Class 0.0 has 594938 voxels and a volume of 594.9380000000001 mm^3
# Class 1.0 has 4412 voxels and a volume of 4.412000000000001 mm^3
# Class 2.0 has 1549 voxels and a volume of 1.5490000000000004 mm^3
# Class 3.0 has 275 voxels and a volume of 0.275 mm^3
# Class 5.0 has 3463 voxels and a volume of 3.4630000000000005 mm^3
# Class 6.0 has 11598 voxels and a volume of 11.598 mm^3
# Class 12.0 has 651 voxels and a volume of 0.6510000000000002 mm^3
# Class 13.0 has 230 voxels and a volume of 0.23000000000000004 mm^3
# Class 15.0 has 1684 voxels and a volume of 1.6840000000000002 mm^3
# Class 16.0 has 10646 voxels and a volume of 10.646000000000003 mm^3
# Class 21.0 has 554 voxels and a volume of 0.5540000000000002 mm^3
# ----------------------------------------------------------//
#
#
#
# |- TBI_EDA_ll_24_04bis_anat_orig.nii.gz -------------------\
#
# Number of classes:  11
#
# - Classes present in the mask:  [ 0.  1.  2.  3.  5.  6. 12. 13. 15. 16. 21.]
# Class 0.0 has 591699 voxels and a volume of 591.6990000000001 mm^3
# Class 1.0 has 5162 voxels and a volume of 5.162000000000001 mm^3
# Class 2.0 has 1501 voxels and a volume of 1.5010000000000001 mm^3
# Class 3.0 has 129 voxels and a volume of 0.129 mm^3
# Class 5.0 has 2847 voxels and a volume of 2.847 mm^3
# Class 6.0 has 15189 voxels and a volume of 15.189000000000002 mm^3
# Class 12.0 has 396 voxels and a volume of 0.3960000000000001 mm^3
# Class 13.0 has 106 voxels and a volume of 0.10600000000000004 mm^3
# Class 15.0 has 1315 voxels and a volume of 1.3150000000000002 mm^3
# Class 16.0 has 11254 voxels and a volume of 11.254000000000003 mm^3
# Class 21.0 has 402 voxels and a volume of 0.4020000000000001 mm^3
# ----------------------------------------------------------//
#
#
#
# |- TBI_EDA_ll_24_06_anat_orig.nii.gz -------------------\
#
# Number of classes:  11
#
# - Classes present in the mask:  [ 0.  1.  2.  3.  5.  6. 12. 13. 15. 16. 21.]
# Class 0.0 has 592491 voxels and a volume of 592.4910000000001 mm^3
# Class 1.0 has 5270 voxels and a volume of 5.2700000000000005 mm^3
# Class 2.0 has 1260 voxels and a volume of 1.2600000000000002 mm^3
# Class 3.0 has 598 voxels and a volume of 0.5980000000000001 mm^3
# Class 5.0 has 3125 voxels and a volume of 3.125 mm^3
# Class 6.0 has 13272 voxels and a volume of 13.272 mm^3
# Class 12.0 has 570 voxels and a volume of 0.5700000000000001 mm^3
# Class 13.0 has 157 voxels and a volume of 0.15700000000000003 mm^3
# Class 15.0 has 1477 voxels and a volume of 1.4770000000000003 mm^3
# Class 16.0 has 11388 voxels and a volume of 11.388 mm^3
# Class 21.0 has 392 voxels and a volume of 0.39200000000000007 mm^3
# ----------------------------------------------------------//
#
#
#
# |- TBI_EDA_ll_24_07_anat_orig.nii.gz -------------------\
#
# Number of classes:  11
#
# - Classes present in the mask:  [ 0.  1.  2.  3.  5.  6. 12. 13. 15. 16. 21.]
# Class 0.0 has 587982 voxels and a volume of 587.9820000000001 mm^3
# Class 1.0 has 3552 voxels and a volume of 3.5520000000000005 mm^3
# Class 2.0 has 1648 voxels and a volume of 1.6480000000000001 mm^3
# Class 3.0 has 753 voxels and a volume of 0.7530000000000001 mm^3
# Class 5.0 has 3724 voxels and a volume of 3.724 mm^3
# Class 6.0 has 16229 voxels and a volume of 16.229000000000003 mm^3
# Class 12.0 has 592 voxels and a volume of 0.5920000000000001 mm^3
# Class 13.0 has 191 voxels and a volume of 0.19100000000000003 mm^3
# Class 15.0 has 2060 voxels and a volume of 2.06 mm^3
# Class 16.0 has 12833 voxels and a volume of 12.833000000000002 mm^3
# Class 21.0 has 436 voxels and a volume of 0.43600000000000005 mm^3
# ----------------------------------------------------------//
#
#
#
# |- TBI_EDA_ll_24_08_anat_orig.nii.gz -------------------\
#
# Number of classes:  11
#
# - Classes present in the mask:  [ 0.  1.  2.  3.  5.  6. 12. 13. 15. 16. 21.]
# Class 0.0 has 588238 voxels and a volume of 588.2380000000002 mm^3
# Class 1.0 has 6010 voxels and a volume of 6.010000000000001 mm^3
# Class 2.0 has 1374 voxels and a volume of 1.3740000000000003 mm^3
# Class 3.0 has 1128 voxels and a volume of 1.1280000000000001 mm^3
# Class 5.0 has 3215 voxels and a volume of 3.215 mm^3
# Class 6.0 has 15554 voxels and a volume of 15.554000000000002 mm^3
# Class 12.0 has 523 voxels and a volume of 0.523 mm^3
# Class 13.0 has 237 voxels and a volume of 0.23700000000000007 mm^3
# Class 15.0 has 1490 voxels and a volume of 1.4900000000000002 mm^3
# Class 16.0 has 11731 voxels and a volume of 11.731000000000002 mm^3
# Class 21.0 has 500 voxels and a volume of 0.5 mm^3
# ----------------------------------------------------------//
#
#
#
# |- TBI_EDA_ll_24_09_anat_orig.nii.gz -------------------\
#
# Number of classes:  11
#
# - Classes present in the mask:  [ 0.  1.  2.  3.  5.  6. 12. 13. 15. 16. 21.]
# Class 0.0 has 589712 voxels and a volume of 589.7120000000001 mm^3
# Class 1.0 has 3624 voxels and a volume of 3.6240000000000006 mm^3
# Class 2.0 has 1492 voxels and a volume of 1.4920000000000002 mm^3
# Class 3.0 has 1106 voxels and a volume of 1.1060000000000003 mm^3
# Class 5.0 has 3518 voxels and a volume of 3.5180000000000002 mm^3
# Class 6.0 has 15227 voxels and a volume of 15.227000000000002 mm^3
# Class 12.0 has 651 voxels and a volume of 0.6510000000000002 mm^3
# Class 13.0 has 177 voxels and a volume of 0.17700000000000002 mm^3
# Class 15.0 has 2001 voxels and a volume of 2.001000000000001 mm^3
# Class 16.0 has 12066 voxels and a volume of 12.066000000000003 mm^3
# Class 21.0 has 426 voxels and a volume of 0.4260000000000001 mm^3
# ----------------------------------------------------------//
#
#
#
# |- TBI_EDA_ll_24_11_anat_orig.nii.gz -------------------\
#
# Number of classes:  11
#
# - Classes present in the mask:  [ 0.  1.  2.  3.  5.  6. 12. 13. 15. 16. 21.]
# Class 0.0 has 590860 voxels and a volume of 590.86 mm^3
# Class 1.0 has 4806 voxels and a volume of 4.806000000000001 mm^3
# Class 2.0 has 1640 voxels and a volume of 1.6400000000000003 mm^3
# Class 3.0 has 499 voxels and a volume of 0.4990000000000001 mm^3
# Class 5.0 has 3002 voxels and a volume of 3.0020000000000002 mm^3
# Class 6.0 has 16010 voxels and a volume of 16.01 mm^3
# Class 12.0 has 460 voxels and a volume of 0.4600000000000001 mm^3
# Class 13.0 has 181 voxels and a volume of 0.18100000000000005 mm^3
# Class 15.0 has 875 voxels and a volume of 0.875 mm^3
# Class 16.0 has 11261 voxels and a volume of 11.261000000000003 mm^3
# Class 21.0 has 406 voxels and a volume of 0.4060000000000001 mm^3
# ----------------------------------------------------------//
#
#
#
# |- TBI_EDA_ll_24_12_anat_orig.nii.gz -------------------\
#
# Number of classes:  11
#
# - Classes present in the mask:  [ 0.  1.  2.  3.  5.  6. 12. 13. 15. 16. 21.]
# Class 0.0 has 587839 voxels and a volume of 587.839 mm^3
# Class 1.0 has 2224 voxels and a volume of 2.224 mm^3
# Class 2.0 has 1412 voxels and a volume of 1.4120000000000004 mm^3
# Class 3.0 has 1381 voxels and a volume of 1.3810000000000002 mm^3
# Class 5.0 has 3250 voxels and a volume of 3.25 mm^3
# Class 6.0 has 13716 voxels and a volume of 13.716000000000003 mm^3
# Class 12.0 has 1444 voxels and a volume of 1.4440000000000002 mm^3
# Class 13.0 has 592 voxels and a volume of 0.5920000000000001 mm^3
# Class 15.0 has 2456 voxels and a volume of 2.4560000000000004 mm^3
# Class 16.0 has 15305 voxels and a volume of 15.305000000000001 mm^3
# Class 21.0 has 381 voxels and a volume of 0.38100000000000006 mm^3
# ----------------------------------------------------------//
#
#
#
# |- TBI_EDA_ll_24_13_anat_orig.nii.gz -------------------\
#
# Number of classes:  11
#
# - Classes present in the mask:  [ 0.  1.  2.  3.  5.  6. 12. 13. 15. 16. 21.]
# Class 0.0 has 589717 voxels and a volume of 589.7170000000001 mm^3
# Class 1.0 has 3254 voxels and a volume of 3.254000000000001 mm^3
# Class 2.0 has 1348 voxels and a volume of 1.3480000000000003 mm^3
# Class 3.0 has 648 voxels and a volume of 0.6480000000000001 mm^3
# Class 5.0 has 3196 voxels and a volume of 3.1960000000000006 mm^3
# Class 6.0 has 14551 voxels and a volume of 14.551000000000002 mm^3
# Class 12.0 has 1140 voxels and a volume of 1.1400000000000001 mm^3
# Class 13.0 has 407 voxels and a volume of 0.40700000000000003 mm^3
# Class 15.0 has 2005 voxels and a volume of 2.0050000000000003 mm^3
# Class 16.0 has 13309 voxels and a volume of 13.309000000000001 mm^3
# Class 21.0 has 425 voxels and a volume of 0.42500000000000004 mm^3
# ----------------------------------------------------------//
#
#
#
# |- TBI_EDA_ll_24_16_anat_orig.nii.gz -------------------\
#
# Number of classes:  11
#
# - Classes present in the mask:  [ 0.  1.  2.  3.  5.  6. 12. 13. 15. 16. 21.]
# Class 0.0 has 590188 voxels and a volume of 590.1880000000001 mm^3
# Class 1.0 has 5121 voxels and a volume of 5.121000000000001 mm^3
# Class 2.0 has 1571 voxels and a volume of 1.5710000000000004 mm^3
# Class 3.0 has 569 voxels and a volume of 0.5690000000000002 mm^3
# Class 5.0 has 3158 voxels and a volume of 3.1580000000000004 mm^3
# Class 6.0 has 14748 voxels and a volume of 14.748000000000003 mm^3
# Class 12.0 has 592 voxels and a volume of 0.5920000000000001 mm^3
# Class 13.0 has 221 voxels and a volume of 0.22100000000000006 mm^3
# Class 15.0 has 1364 voxels and a volume of 1.364 mm^3
# Class 16.0 has 12015 voxels and a volume of 12.015 mm^3
# Class 21.0 has 453 voxels and a volume of 0.45300000000000007 mm^3
# ----------------------------------------------------------//
#
#
#
# |- TBI_EDA_ll_24_17_anat_orig.nii.gz -------------------\
#
# Number of classes:  11
#
# - Classes present in the mask:  [ 0.  1.  2.  3.  5.  6. 12. 13. 15. 16. 21.]
# Class 0.0 has 597873 voxels and a volume of 597.873 mm^3
# Class 1.0 has 3295 voxels and a volume of 3.2950000000000004 mm^3
# Class 2.0 has 1329 voxels and a volume of 1.3290000000000002 mm^3
# Class 3.0 has 456 voxels and a volume of 0.45600000000000007 mm^3
# Class 5.0 has 2956 voxels and a volume of 2.9560000000000004 mm^3
# Class 6.0 has 13243 voxels and a volume of 13.243000000000004 mm^3
# Class 12.0 has 444 voxels and a volume of 0.44400000000000006 mm^3
# Class 13.0 has 22 voxels and a volume of 0.022000000000000006 mm^3
# Class 15.0 has 1564 voxels and a volume of 1.564 mm^3
# Class 16.0 has 8476 voxels and a volume of 8.476 mm^3
# Class 21.0 has 342 voxels and a volume of 0.3420000000000001 mm^3
# ----------------------------------------------------------//
#
#
#
# |- TBI_EDA_ll_24_18_anat_orig.nii.gz -------------------\
#
# Number of classes:  11
#
# - Classes present in the mask:  [ 0.  1.  2.  3.  5.  6. 12. 13. 15. 16. 21.]
# Class 0.0 has 587099 voxels and a volume of 587.099 mm^3
# Class 1.0 has 6365 voxels and a volume of 6.365000000000001 mm^3
# Class 2.0 has 1691 voxels and a volume of 1.6910000000000005 mm^3
# Class 3.0 has 708 voxels and a volume of 0.7080000000000001 mm^3
# Class 5.0 has 3304 voxels and a volume of 3.3040000000000007 mm^3
# Class 6.0 has 15560 voxels and a volume of 15.560000000000002 mm^3
# Class 12.0 has 666 voxels and a volume of 0.6660000000000001 mm^3
# Class 13.0 has 175 voxels and a volume of 0.17500000000000002 mm^3
# Class 15.0 has 1456 voxels and a volume of 1.4560000000000002 mm^3
# Class 16.0 has 12502 voxels and a volume of 12.502000000000002 mm^3
# Class 21.0 has 474 voxels and a volume of 0.47400000000000014 mm^3
# ----------------------------------------------------------//
#
#
#
# |- TBI_EDA_ll_24_19_anat_orig.nii.gz -------------------\
#
# Number of classes:  11
#
# - Classes present in the mask:  [ 0.  1.  2.  3.  5.  6. 12. 13. 15. 16. 21.]
# Class 0.0 has 587901 voxels and a volume of 587.9010000000002 mm^3
# Class 1.0 has 4961 voxels and a volume of 4.961000000000001 mm^3
# Class 2.0 has 1817 voxels and a volume of 1.8170000000000002 mm^3
# Class 3.0 has 610 voxels and a volume of 0.6100000000000001 mm^3
# Class 5.0 has 3337 voxels and a volume of 3.3370000000000006 mm^3
# Class 6.0 has 16469 voxels and a volume of 16.469000000000005 mm^3
# Class 12.0 has 766 voxels and a volume of 0.7660000000000001 mm^3
# Class 13.0 has 183 voxels and a volume of 0.18300000000000002 mm^3
# Class 15.0 has 1408 voxels and a volume of 1.4080000000000004 mm^3
# Class 16.0 has 12234 voxels and a volume of 12.234000000000002 mm^3
# Class 21.0 has 314 voxels and a volume of 0.31400000000000006 mm^3
# ----------------------------------------------------------//
#
#
#
# |- TBI_EDA_ll_24_20_anat_orig.nii.gz -------------------\
#
# Number of classes:  11
#
# - Classes present in the mask:  [ 0.  1.  2.  3.  5.  6. 12. 13. 15. 16. 21.]
# Class 0.0 has 594174 voxels and a volume of 594.1740000000001 mm^3
# Class 1.0 has 4528 voxels and a volume of 4.5280000000000005 mm^3
# Class 2.0 has 1412 voxels and a volume of 1.4120000000000004 mm^3
# Class 3.0 has 372 voxels and a volume of 0.3720000000000001 mm^3
# Class 5.0 has 3150 voxels and a volume of 3.1500000000000004 mm^3
# Class 6.0 has 13836 voxels and a volume of 13.836000000000002 mm^3
# Class 12.0 has 548 voxels and a volume of 0.548 mm^3
# Class 13.0 has 69 voxels and a volume of 0.069 mm^3
# Class 15.0 has 1221 voxels and a volume of 1.221 mm^3
# Class 16.0 has 10240 voxels and a volume of 10.240000000000002 mm^3
# Class 21.0 has 450 voxels and a volume of 0.45 mm^3
# ----------------------------------------------------------//
#
#
#
# |- TBI_EDA_ll_24_21_anat_orig.nii.gz -------------------\
#
# Number of classes:  11
#
# - Classes present in the mask:  [ 0.  1.  2.  3.  5.  6. 12. 13. 15. 16. 21.]
# Class 0.0 has 590880 voxels and a volume of 590.88 mm^3
# Class 1.0 has 4480 voxels and a volume of 4.48 mm^3
# Class 2.0 has 1664 voxels and a volume of 1.6640000000000001 mm^3
# Class 3.0 has 619 voxels and a volume of 0.6190000000000002 mm^3
# Class 5.0 has 3313 voxels and a volume of 3.3130000000000006 mm^3
# Class 6.0 has 15369 voxels and a volume of 15.369000000000003 mm^3
# Class 12.0 has 587 voxels and a volume of 0.5870000000000001 mm^3
# Class 13.0 has 218 voxels and a volume of 0.21800000000000003 mm^3
# Class 15.0 has 1392 voxels and a volume of 1.3920000000000003 mm^3
# Class 16.0 has 10999 voxels and a volume of 10.999000000000002 mm^3
# Class 21.0 has 479 voxels and a volume of 0.4790000000000001 mm^3
# ----------------------------------------------------------//
#
#
#
# |- TBI_EDA_ll_24_22_anat_orig.nii.gz -------------------\
#
# Number of classes:  11
#
# - Classes present in the mask:  [ 0.  1.  2.  3.  5.  6. 12. 13. 15. 16. 21.]
# Class 0.0 has 588309 voxels and a volume of 588.3090000000001 mm^3
# Class 1.0 has 5631 voxels and a volume of 5.631 mm^3
# Class 2.0 has 1666 voxels and a volume of 1.6660000000000004 mm^3
# Class 3.0 has 1001 voxels and a volume of 1.0010000000000001 mm^3
# Class 5.0 has 3356 voxels and a volume of 3.3560000000000003 mm^3
# Class 6.0 has 15340 voxels and a volume of 15.340000000000002 mm^3
# Class 12.0 has 636 voxels and a volume of 0.6360000000000001 mm^3
# Class 13.0 has 139 voxels and a volume of 0.139 mm^3
# Class 15.0 has 1599 voxels and a volume of 1.5990000000000002 mm^3
# Class 16.0 has 11862 voxels and a volume of 11.862000000000002 mm^3
# Class 21.0 has 461 voxels and a volume of 0.4610000000000001 mm^3
# ----------------------------------------------------------//
#
#
#
# |- TBI_EDA_ll_24_23_anat_orig.nii.gz -------------------\
#
# Number of classes:  11
#
# - Classes present in the mask:  [ 0.  1.  2.  3.  5.  6. 12. 13. 15. 16. 21.]
# Class 0.0 has 585716 voxels and a volume of 585.7160000000001 mm^3
# Class 1.0 has 5656 voxels and a volume of 5.656000000000001 mm^3
# Class 2.0 has 1889 voxels and a volume of 1.8890000000000002 mm^3
# Class 3.0 has 796 voxels and a volume of 0.7960000000000002 mm^3
# Class 5.0 has 3173 voxels and a volume of 3.1730000000000005 mm^3
# Class 6.0 has 16744 voxels and a volume of 16.744000000000003 mm^3
# Class 12.0 has 719 voxels and a volume of 0.7190000000000002 mm^3
# Class 13.0 has 303 voxels and a volume of 0.30300000000000005 mm^3
# Class 15.0 has 1258 voxels and a volume of 1.2580000000000002 mm^3
# Class 16.0 has 13273 voxels and a volume of 13.273000000000003 mm^3
# Class 21.0 has 473 voxels and a volume of 0.4730000000000001 mm^3
# ----------------------------------------------------------//
#
#
#
# |- TBI_EDA_ll_24_24_anat_orig.nii.gz -------------------\
#
# Number of classes:  11
#
# - Classes present in the mask:  [ 0.  1.  2.  3.  5.  6. 12. 13. 15. 16. 21.]
# Class 0.0 has 590816 voxels and a volume of 590.8160000000001 mm^3
# Class 1.0 has 3408 voxels and a volume of 3.408000000000001 mm^3
# Class 2.0 has 1350 voxels and a volume of 1.35 mm^3
# Class 3.0 has 788 voxels and a volume of 0.7880000000000003 mm^3
# Class 5.0 has 3069 voxels and a volume of 3.069000000000001 mm^3
# Class 6.0 has 15783 voxels and a volume of 15.783000000000005 mm^3
# Class 12.0 has 569 voxels and a volume of 0.5690000000000002 mm^3
# Class 13.0 has 184 voxels and a volume of 0.18400000000000005 mm^3
# Class 15.0 has 1381 voxels and a volume of 1.3810000000000002 mm^3
# Class 16.0 has 12156 voxels and a volume of 12.156000000000002 mm^3
# Class 21.0 has 496 voxels and a volume of 0.4960000000000001 mm^3
# ----------------------------------------------------------//
#
#
#
# |- TBI_EDA_ll_24_25_anat_orig.nii.gz -------------------\
#
# Number of classes:  11
#
# - Classes present in the mask:  [ 0.  1.  2.  3.  5.  6. 12. 13. 15. 16. 21.]
# Class 0.0 has 586141 voxels and a volume of 586.1410000000001 mm^3
# Class 1.0 has 3031 voxels and a volume of 3.0310000000000006 mm^3
# Class 2.0 has 1653 voxels and a volume of 1.6530000000000002 mm^3
# Class 3.0 has 1423 voxels and a volume of 1.4230000000000003 mm^3
# Class 5.0 has 3546 voxels and a volume of 3.5460000000000003 mm^3
# Class 6.0 has 14793 voxels and a volume of 14.793000000000005 mm^3
# Class 12.0 has 1417 voxels and a volume of 1.4170000000000003 mm^3
# Class 13.0 has 833 voxels and a volume of 0.8330000000000002 mm^3
# Class 15.0 has 2767 voxels and a volume of 2.7670000000000003 mm^3
# Class 16.0 has 13874 voxels and a volume of 13.874000000000002 mm^3
# Class 21.0 has 522 voxels and a volume of 0.5220000000000001 mm^3
# ----------------------------------------------------------//
#
#
# Processing 23 subjects...
# I:\\DannoCerebraleAcuto_MRI\\EDA\\1months\TBI_EDA_ll_24_01\Anat\TBI_EDA_ll_24_01_regions_r3dnet_DA.nii.gz
# I:\\DannoCerebraleAcuto_MRI\\EDA\\1months\TBI_EDA_ll_24_02\Anat\TBI_EDA_ll_24_02_regions_r3dnet_DA.nii.gz
# I:\\DannoCerebraleAcuto_MRI\\EDA\\1months\TBI_EDA_ll_24_03\Anat\TBI_EDA_ll_24_03_regions_r3dnet_DA.nii.gz
# I:\\DannoCerebraleAcuto_MRI\\EDA\\1months\TBI_EDA_ll_24_04\Anat\TBI_EDA_ll_24_04_regions_r3dnet_DA.nii.gz
# I:\\DannoCerebraleAcuto_MRI\\EDA\\1months\TBI_EDA_ll_24_04bis\Anat\TBI_EDA_ll_24_04bis_regions_r3dnet_DA.nii.gz
# I:\\DannoCerebraleAcuto_MRI\\EDA\\1months\TBI_EDA_ll_24_06\Anat\TBI_EDA_ll_24_06_regions_r3dnet_DA.nii.gz
# I:\\DannoCerebraleAcuto_MRI\\EDA\\1months\TBI_EDA_ll_24_07\Anat\TBI_EDA_ll_24_07_regions_r3dnet_DA.nii.gz
# I:\\DannoCerebraleAcuto_MRI\\EDA\\1months\TBI_EDA_ll_24_08\Anat\TBI_EDA_ll_24_08_regions_r3dnet_DA.nii.gz
# I:\\DannoCerebraleAcuto_MRI\\EDA\\1months\TBI_EDA_ll_24_09\Anat\TBI_EDA_ll_24_09_regions_r3dnet_DA.nii.gz
# I:\\DannoCerebraleAcuto_MRI\\EDA\\1months\TBI_EDA_ll_24_10\Anat\TBI_EDA_ll_24_10_regions_r3dnet_DA.nii.gz
# Prediction not found for TBI_EDA_ll_24_10
# Brain mask not found for TBI_EDA_ll_24_10
# I:\\DannoCerebraleAcuto_MRI\\EDA\\1months\TBI_EDA_ll_24_11\Anat\TBI_EDA_ll_24_11_regions_r3dnet_DA.nii.gz
# I:\\DannoCerebraleAcuto_MRI\\EDA\\1months\TBI_EDA_ll_24_12\Anat\TBI_EDA_ll_24_12_regions_r3dnet_DA.nii.gz
# I:\\DannoCerebraleAcuto_MRI\\EDA\\1months\TBI_EDA_ll_24_13\Anat\TBI_EDA_ll_24_13_regions_r3dnet_DA.nii.gz
# I:\\DannoCerebraleAcuto_MRI\\EDA\\1months\TBI_EDA_ll_24_16\Anat\TBI_EDA_ll_24_16_regions_r3dnet_DA.nii.gz
# I:\\DannoCerebraleAcuto_MRI\\EDA\\1months\TBI_EDA_ll_24_17\Anat\TBI_EDA_ll_24_17_regions_r3dnet_DA.nii.gz
# I:\\DannoCerebraleAcuto_MRI\\EDA\\1months\TBI_EDA_ll_24_18\Anat\TBI_EDA_ll_24_18_regions_r3dnet_DA.nii.gz
# I:\\DannoCerebraleAcuto_MRI\\EDA\\1months\TBI_EDA_ll_24_19\Anat\TBI_EDA_ll_24_19_regions_r3dnet_DA.nii.gz
# I:\\DannoCerebraleAcuto_MRI\\EDA\\1months\TBI_EDA_ll_24_20\Anat\TBI_EDA_ll_24_20_regions_r3dnet_DA.nii.gz
# I:\\DannoCerebraleAcuto_MRI\\EDA\\1months\TBI_EDA_ll_24_21\Anat\TBI_EDA_ll_24_21_regions_r3dnet_DA.nii.gz
# I:\\DannoCerebraleAcuto_MRI\\EDA\\1months\TBI_EDA_ll_24_22\Anat\TBI_EDA_ll_24_22_regions_r3dnet_DA.nii.gz
# I:\\DannoCerebraleAcuto_MRI\\EDA\\1months\TBI_EDA_ll_24_23\Anat\TBI_EDA_ll_24_23_regions_r3dnet_DA.nii.gz
# I:\\DannoCerebraleAcuto_MRI\\EDA\\1months\TBI_EDA_ll_24_24\Anat\TBI_EDA_ll_24_24_regions_r3dnet_DA.nii.gz
# I:\\DannoCerebraleAcuto_MRI\\EDA\\1months\TBI_EDA_ll_24_25\Anat\TBI_EDA_ll_24_25_regions_r3dnet_DA.nii.gz
